# %% [markdown]
# # Mise à disposition du jeu de données stroke_dataset via une API REST

# %% [markdown]
# ## Description du dataset
#
# Le jeu de données utilisé provient de Kaggle : [Stroke Prediction Dataset](https://www.kaggle.com/datasets/fedesoriano/stroke-prediction-dataset).
# Il contient des données de patients avec différentes caractéristiques médicales et sociales, ainsi que l'information si le patient a subi un accident vasculaire cérébral (AVC) ou non.
#
# Télécharger les données et ajouter les dans un dossier data/.
#
# Les colonnes des données sont :
# - `id` : Identifiant unique du patient
# - `gender` : Sexe
# - `age` : Âge
# - `hypertension` : Présence d'hypertension (0 ou 1)
# - `heart_disease` : Présence de maladie cardiaque (0 ou 1)
# - `ever_married` : Statut marital
# - `work_type` : Type d'emploi
# - `Residence_type` : Urbaine ou rurale
# - `avg_glucose_level` : Moyenne du taux de glucose
# - `bmi` : Indice de masse corporelle
# - `smoking_status` : Statut tabagique
# - `stroke` : Présence d'AVC (0 ou 1)
#
# ## Projet
#
# Vous devez exposer les données patients du jeu de données via une API REST afin que les données soit utilisables par d'autres équipes (médecins, data science, étude, etc.).
#
# Cette API REST sera développée avec FastAPI et les spécifications sont les suivantes :
# | Méthode | Endpoint                                      | Fonctionnalité                                                                                                    |
# | ------- | --------------------------------------------- | ----------------------------------------------------------------------------------------------------------------- |
# | `GET`   | `/patients/{id}`                              | Récupère les détails d’un patient donné (via son identifiant unique)                                              |
# | `GET`   | `/patients?stroke=1&gender=Female&max_age=60` | Renvoie les patients filtrés selon plusieurs critères : AVC (oui/non), genre, âge maximal                         |
# | `GET`   | `/stats/`                                     | Fournit des statistiques agrégées sur les patients (ex. : nb total de patients, âge moyen, taux d’AVC, répartition hommes/femmes, etc.) |
#
#
#
# ---
#
# ## Quelques définitions
#
#
# 1. Qu’est-ce qu’une API REST ?
#
# - API signifie Application Programming Interface (Interface de Programmation d’Application). C’est un ensemble de règles et de protocoles qui permettent à des logiciels de communiquer entre eux.
# - REST signifie Representational State Transfer. C’est un style architectural pour concevoir des services web.
# Il en existe d'autres mais REST est celui que vous rencontrerez le plus souvent.
# - Vous avez utilisé une API REST via l'API Google Books.
#
# - A quoi sert une API REST ?
#
#     - Permet à différentes applications de communiquer facilement, même si elles sont écrites dans des langages différents.
#     - Permet d’accéder à des services distants (ex : bases de données, services web) de manière standardisée.
#     - Facilite la création d’applications modulaires et évolutives (front-end, back-end, mobile, etc.)
#
# 2. Principes clés d’une API REST
#
# - a. Utilisation du protocole HTTP
# Les échanges entre client et serveur utilisent des méthodes HTTP standard comme :
#
#     - GET : pour récupérer des données
#     - POST : pour envoyer ou créer des données
#     - PUT : pour mettre à jour des données
#     - DELETE : pour supprimer des données
#
# - b. Accès aux ressources via des URLs
#
# Chaque ressource (par exemple un livre, un utilisateur) est accessible via une URL unique.
#
# Exemple fictif:
#     https://api.example.com/books/123 pour accéder au livre d’identifiant 123.
#
# - c. Stateless (sans état)
#
# Le serveur ne conserve aucune information sur le client entre deux requêtes. Chaque requête doit contenir toutes les informations nécessaires.
#
# - d. Représentations des données
#
# Les données sont envoyées et reçues généralement en format JSON ou XML, qui sont faciles à lire et à manipuler.
#
# - e. Utilisation de codes status HTTP
#
# Chaque réponse du serveur est accompagnée d’un code HTTP indiquant le résultat de la requête. (cf [liste des codes](https://developer.mozilla.org/en-US/docs/Web/HTTP/Reference/Status))
#
# ## Outils utilisés
# 1. FastAPI
#
# FastAPI est un framework Python moderne, rapide et très utilisé dans le milieu professionnel pour construire des API REST.
#
# Il permet :
# - une définition simple des routes et des paramètres
# - La génération automatique de documentation interactive (Swagger UI)
# - FastAPI lit les requêtes entrantes, les traite avec ton code Python, et retourne une réponse HTTP (en JSON).
#
# 2. Uvicorn : exécute l'application FastAPI
#
# - Uvicorn est un serveur ASGI (Asynchronous Server Gateway Interface) : c'est une interface standard pour gérer les requêtes de manière asynchrone et performante, notamment utile pour les applications modernes.
# - Il attend les requêtes HTTP (par exemple depuis un navigateur), les transmet à FastAPI, et renvoie la réponse.
# - Uvicorn permet à l'API de fonctionner : sans Uvicorn ou un autre serveur, FastAPI ne peut pas fonctionner.
#
#
# 3. Swagger UI : l’interface de doc et test interactive
#
# - Swagger UI est généré automatiquement par FastAPI.
# - C’est une interface web qui permet de :
#     - Voir toutes les routes disponibles dans l'API
#     - Tester les routes en envoyant des requêtes sans écrire de code (bouton try it out)
#     - Voir les paramètres attendus et les formats de réponse
#
# 4. Résumé des interactions
#
# - Tester la route de base de l'API grâce à la commande :
# ```bash
#     poetry run fastapi dev stroke_api/main.py
# ```
#
# --> Qu'est-ce qu'il se passe derrière cette commande ?
#
# - Uvicorn démarre un serveur local
# - FastAPI génère automatiquement une interface : Swagger UI, accessible sur http://127.0.0.1:8000/docs qui affiche toutes les routes définies dans le code python FastAPI
# - Quand on clique sur "Try it out" dans Swagger UI, Swagger envoie une requête HTTP au serveur (ici Uvicorn)
# - Le serveur (Uvicorn) la reçoit, l’envoie à FastAPI, qui traite et renvoie une réponse
# - Swagger UI affiche la réponse de l’API (par ex : liste de patients)

# %% [markdown]
# ---
#
# Import des bibliothèques utiles au projet

# %%
import pandas as pd
import fastapi as fp
import plotly_express as px

# %% [markdown]
# ## 1. Prétraitement des données / Data preprocessing
#
# Les données réelles sont rarement prêtes à être utilisées directement. Elles peuvent contenir des erreurs, des valeurs manquantes, des doublons, des formats incohérents, ou ne pas être adaptées au modèle ou au système cible.
#
# Le prétraitement consiste à nettoyer, structurer et transformer les données brutes avant de les exploiter dans un projet (modèle IA, API, visualisation, etc.).
#
# Vous avez déjà prétraité des données, petit rappel des éléments sur lesquels travailler dans un prétraitment classique et les méthodes pandas qu'il est possible d'utiliser pour les différentes étapes (des exemples d'utilisation des méthodes pandas sont disponibles dans la doc) :
# - explorer les données pour identifier les types de données, valeurs manquantes, incohérence ([info](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.info.html), [dtypes](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dtypes.html))
# - adapter les types si nécessaire ([astypes](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.astype.html))
# - identifier les doublons et les supprimer s'il y en a ([duplicated](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.duplicated.html), [drop_duplicates](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop_duplicates.html))
# - traiter les valeurs manquantes s'il y en a ([fillna](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.fillna.html), [dropna](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dropna.html), [replace](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.replace.html))
# - identifier les incohérences éventuelles (valeurs aberrantes/outliers) en vérifiant si les valeurs min, max, moyennes sont raisonnables (recherche internet si nécessaire) ([describe](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.describe.html)), et les traiter.
# - Traiter les valeurs aberrantes si vous en détectez ([loc](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.loc.html) pour récupérer les lignes qui répondent à une certaine condition, cf exemple ci-dessous)
#
#
# **Exemple df.loc :**
#
# Récupérer toutes les lignes de df telles que la valeur de "nom de colonne" >= 0
#
# ```df_subset = df.loc[stroke_data_df['nom de colonne'] >= 0]```

# %% [markdown]
# ---
# ### **TODO**
# 1.a. Prétraiter les données du dataset.
#
#
# 1.b. Documenter dans le README.md :
# - Les étapes de prétraitement,
# - Justification des choix concernant le traitement des valeurs manquantes (si besoin),
# - Liste des valeurs raisonnables utilisées pour détecter les valeurs aberrantes,
# - Justification des choix pour traiter les valeurs aberrantes (si besoin).
#
# 2.a. Chercher des infos sur le format de fichier parquet et indiquer les sources consultées :
# - Différence principale avec le format csv ?
# - Dans quels cas l'utiliser ?
# - Pourquoi c'est un format adapté aux gros volumes de données ?
#
#
#
# 2.b. Sauvegarder les données prétraiteées dans un fichier parquet ([to_parquet](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.to_parquet.html)).

# %% [markdown]
# ---
# ## 1. Prétraitement

# %% [markdown]
#  ### 1.a Prétraitement des données

# %%
# Prétraitement de données

df = pd.read_csv("../data/healthcare-dataset-stroke-data.csv")

df
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0           Private          Urban             228.69  36.6  formerly smoked
# 1     Self-employed          Rural             202.21   NaN     never smoked
# 2           Private          Rural             105.92  32.5     never smoked
# 3           Private          Urban             171.23  34.4           smokes
# 4     Self-employed          Rural             174.12  24.0     never smoked
# ...             ...            ...                ...   ...              ...
# 5105        Private          Urban              83.75   NaN     never smoked
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 5105       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0
#
# [5110 rows x 12 columns]

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB
# None

# %% [markdown]
# On voit qu'il y a des données manquantes dans BMI. Les colonnes "ever_married","hypertension","heart disease","residence type" et "stroke" devrait être en boolean.
# "work type" et "smoking status" en categorical ou string (plusieurs choix)

# %%
print(df.describe())
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  4909.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.854067     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.500000     0.000000
# 50%            91.885000    28.100000     0.000000
# 75%           114.090000    33.100000     0.000000
# max           271.740000    97.600000     1.000000

# %% [markdown]
# Rien d'anormal dans ces données numériques.

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5105    False
# 5106    False
# 5107    False
# 5108    False
# 5109    False
# Length: 5110, dtype: bool

# %% [markdown]
# Aucun doublon.

# %% [markdown]
# On va regarder les valeurs uniques pour les colonnes d'object.

# %%
print(pd.unique(df['work_type']))
print(pd.unique(df['Residence_type']))
print(pd.unique(df['smoking_status']))
print(pd.unique(df['gender']))
# Out:
# ['Private' 'Self-employed' 'Govt_job' 'children' 'Never_worked']
# ['Urban' 'Rural']
# ['formerly smoked' 'never smoked' 'smokes' 'Unknown']
# ['Male' 'Female' 'Other']

# %% [markdown]
# On va convertir les différents type de données comme écrit précédemment. Les colonnes "ever_married","hypertension","heart disease" et "stroke" devrait être en boolean.
# "work type", "residence type", "smoking status" et "gender" en categorical ou string (plusieurs choix)
# On voit aussi que les valeurs ne sont pas toutes en majuscules, certaines ont des espaces, d'autre non.
# On décide de tout écrire en majuscule et de remplacer les _ par des espaces.

# %%
df["ever_married"] = df["ever_married"].map({"Yes": True, "No": False})
df["ever_married"] = df["ever_married"].astype("bool")
df["gender"] = df["gender"].astype("category")
df["hypertension"] = df["hypertension"].astype("bool")
df["heart_disease"] = df["heart_disease"].astype("bool")
df["stroke"] = df["stroke"].astype("bool")
df["work_type"] = df["work_type"].map({"Govt_job": "Government job", "children": "Children", "Never_worked":"Never worked", "Private":"Private", "Self-employed":"Self-employed"})
df["work_type"] = df["work_type"].astype("category")
df["Residence_type"] = df["Residence_type"].astype("category")
df["smoking_status"] = df["smoking_status"].map({"formerly smoked": "Formerly smoked", "never smoked": "Never smoked", "smokes":"Smokes", "Unknown":"Unknown"})
df["smoking_status"] = df["smoking_status"].astype("category")
df.dtypes
# Out:
# id                      int64
# gender               category
# age                   float64
# hypertension             bool
# heart_disease            bool
# ever_married             bool
# work_type            category
# Residence_type       category
# avg_glucose_level     float64
# bmi                   float64
# smoking_status       category
# stroke                   bool
# dtype: object

# %% [markdown]
# Hypothèse : Le taux de glucose dans le sang a un lien avec le BMI. Si c'est le cas, on peut utiliser le taux de glucose pour estimer les valeurs manquantes dans la colonne de BMI.

# %%
df['glucose_normalized'] = (df['avg_glucose_level'] - df['avg_glucose_level'].min()) / (df['avg_glucose_level'].max() - df['avg_glucose_level'].min())
df['bmi_normalized'] = (df['bmi'] - df['bmi'].min()) / (df['bmi'].max() - df['bmi'].min())
fig = px.histogram(df, x=["glucose_normalized", "bmi_normalized"], barmode="group")
fig.show()

# %% [markdown]
# On peut observer une certaine corrélation entre le taux de glucose et la BMI.
# On calcule le coefficient de variation de la BMI et du glucose.

# %%
CV_glucose = df["avg_glucose_level"].std() / df["avg_glucose_level"].mean()*100
CV_bmi = df["bmi"].std() / df["bmi"].mean()*100
print(f"{round(CV_glucose)}%", f"{round(CV_bmi)}%")
# Out:
# 43% 27%

# %% [markdown]
# En prenant en considération les coefficients de variation assez haut, on va donc utiliser la médiane des 2 valeurs plutôt que la moyenne.
# En divisant la médiane de la BMI par la médiane du taux de glucose, on obtient un coefficient multiplicateur qui va nous permettre de créer une fonction afin d'estimer une valeur pour la BMI en fonction du taux de glucose.

# %%
gluc_median = df["avg_glucose_level"].median()
bmi_median = df["bmi"].median()
func = bmi_median / gluc_median
print(gluc_median, bmi_median, func)
# Out:
# 91.88499999999999 28.1 0.3058170539261033

# %%
coef = df["bmi"].median() / df["avg_glucose_level"].median()

# Remplacer les NaN dans 'bmi'

df.loc[df["bmi"].isnull(), "bmi"] = (df.loc[df["bmi"].isnull(), "avg_glucose_level"] * coef)
df["bmi"] = df["bmi"].round(1)

# Drop les colonnes "normalized"

df = df.drop(columns=["bmi_normalized", "glucose_normalized"])

# %% [markdown]
# ### 2. Informations sur le type de fichier "parquet"

# %% [markdown]
# #### 2.a Le format "parquet"

# %% [markdown]
# - Différence principale avec le format csv ?
# Le csv est une format texte simple, sauvegarde les données par ligne, séparation virgule.
# Le parquet est une format binaire colonnaire, qui stocke les données colonne par colonne, avec compression et conversation des types de données.
# Le parquet est beaucoup plus rapide car il est capable de lire que certain colonnes à la fois sans lire les tout les données. Les fichiers sont beaucoup plus petits (grâce à la compression et au stockage colonnaire). Par contre, un CSV est plus simple à lire et partager, mais plus volumineux et plus lent sur les grand jeux de données.
#
# - Dans quels cas l'utiliser ?
# Quant on travaille avec les données massives (machine learning, data engineering) ou on veut lire que certaines colonnes rapidement, et aussi pour archiver ou transfporter de gros ensembles des données en minimalisant la taille.
#
# - Pourquoi c'est un format adapté aux gros volumes de données ?
# Le stockage colonnaire permet de lire uniquement les colonnes nécessaires, donc on gagne le temps et des entrées/sorties disque sont reduit.
# Le compression reduit la taille de fichiers (moins de stockage, transfert plus rapide)
# Conservation des types : pas besoin de parser/convertir les valeurs (contrairement au CSV), ce qui accélère le traitement.

# %% [markdown]
# #### 2.b Enregistrement au format parquet

# %%
df.to_parquet('../data/healthcare-dataset-stroke-data-clean.parquet', index=False)

# %% [markdown]
# -----
# ## Développement de l'API
#
# A présent que les données sont propres, on peut débuter la création de l'API.
#
# Pour cela, vous allez avoir besoin de quelques fonctions permettant de filtrer les données.
#
# Vous allez les définir ci-dessous, ce qui vous permettra de les tester puis les fonctions seront reportées dans le fichier filters.py.

# %% [markdown]
# ## Route `/patients/`
# - Cette route retourne une liste filtrée de patients
# - On souhaite pouvoir filtrer par `gender`, `stroke` ou `max_age`
#
# L'objectif est ici de définir une fonction python qui prend en entrée les paramètres optionnels : _gender_, *stroke*, *max_age* et qui renvoie un dictionnaire filtré des données.
#
# On décompose la rédaction de cette fonction en plusieurs étapes.
#
# Dans un premier temps, écrire et tester les filtres que l'on souhaite appliquer sur les données (utiliser [loc](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.loc.html))

# %%
# Filtrer le dataframe pour ne garder que les patients pour lesquels "stroke=1"
df.loc[df["stroke"] == 1]
# Out:
#         id  gender   age  hypertension  heart_disease  ever_married  \
# 0     9046    Male  67.0         False           True          True
# 1    51676  Female  61.0         False          False          True
# 2    31112    Male  80.0         False           True          True
# 3    60182  Female  49.0         False          False          True
# 4     1665  Female  79.0          True          False          True
# ..     ...     ...   ...           ...            ...           ...
# 244  17739    Male  57.0         False          False          True
# 245  49669  Female  14.0         False          False         False
# 246  27153  Female  75.0         False          False          True
# 247  34060    Male  71.0          True          False          True
# 248  43424  Female  78.0         False          False          True
#
#          work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0          Private          Urban             228.69  36.6  Formerly smoked
# 1    Self-employed          Rural             202.21  61.8     Never smoked
# 2          Private          Rural             105.92  32.5     Never smoked
# 3          Private          Urban             171.23  34.4           Smokes
# 4    Self-employed          Rural             174.12  24.0     Never smoked
# ..             ...            ...                ...   ...              ...
# 244        Private          Rural              84.96  36.7          Unknown
# 245       Children          Rural              57.93  30.9          Unknown
# 246  Self-employed          Rural              78.80  29.3  Formerly smoked
# 247  Self-employed          Rural              87.80  26.9          Unknown
# 248        Private          Rural              78.81  19.6          Unknown
#
#      stroke
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# ..      ...
# 244    True
# 245    True
# 246    True
# 247    True
# 248    True
#
# [249 rows x 12 columns]

# %%
# Filtrer les données pour ne garder que les patients pour lesquels "gender="male"
df.loc[df["gender"] == "Male"]
# Out:
#          id gender   age  hypertension  heart_disease  ever_married  \
# 0      9046   Male  67.0         False           True          True
# 2     31112   Male  80.0         False           True          True
# 5     56669   Male  81.0         False          False          True
# 6     53882   Male  74.0          True           True          True
# 13     8213   Male  78.0         False           True          True
# ...     ...    ...   ...           ...            ...           ...
# 5097  64520   Male  68.0         False          False          True
# 5098    579   Male   9.0         False          False         False
# 5099   7293   Male  40.0         False          False          True
# 5100  68398   Male  82.0          True          False          True
# 5108  37544   Male  51.0         False          False          True
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0           Private          Urban             228.69  36.6  Formerly smoked
# 2           Private          Rural             105.92  32.5     Never smoked
# 5           Private          Urban             186.21  29.0  Formerly smoked
# 6           Private          Rural              70.09  27.4     Never smoked
# 13          Private          Urban             219.84  67.2          Unknown
# ...             ...            ...                ...   ...              ...
# 5097  Self-employed          Urban              91.68  40.8          Unknown
# 5098       Children          Urban              71.88  17.5          Unknown
# 5099        Private          Rural              83.94  25.7           Smokes
# 5100  Self-employed          Rural              71.97  28.3     Never smoked
# 5108        Private          Rural             166.29  25.6  Formerly smoked
#
#       stroke
# 0       True
# 2       True
# 5       True
# 6       True
# 13      True
# ...      ...
# 5097   False
# 5098   False
# 5099   False
# 5100   False
# 5108   False
#
# [2115 rows x 12 columns]

# %%
# Filtrer les données pour ne garder que les patients tels que "age <= max_age"
df.loc[df["age"] <= df['age'].max()]
# Out:
#          id  gender   age  hypertension  heart_disease  ever_married  \
# 0      9046    Male  67.0         False           True          True
# 1     51676  Female  61.0         False          False          True
# 2     31112    Male  80.0         False           True          True
# 3     60182  Female  49.0         False          False          True
# 4      1665  Female  79.0          True          False          True
# ...     ...     ...   ...           ...            ...           ...
# 5105  18234  Female  80.0          True          False          True
# 5106  44873  Female  81.0         False          False          True
# 5107  19723  Female  35.0         False          False          True
# 5108  37544    Male  51.0         False          False          True
# 5109  44679  Female  44.0         False          False          True
#
#            work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0            Private          Urban             228.69  36.6  Formerly smoked
# 1      Self-employed          Rural             202.21  61.8     Never smoked
# 2            Private          Rural             105.92  32.5     Never smoked
# 3            Private          Urban             171.23  34.4           Smokes
# 4      Self-employed          Rural             174.12  24.0     Never smoked
# ...              ...            ...                ...   ...              ...
# 5105         Private          Urban              83.75  25.6     Never smoked
# 5106   Self-employed          Urban             125.20  40.0     Never smoked
# 5107   Self-employed          Rural              82.99  30.6     Never smoked
# 5108         Private          Rural             166.29  25.6  Formerly smoked
# 5109  Government job          Urban              85.28  26.2          Unknown
#
#       stroke
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
# ...      ...
# 5105   False
# 5106   False
# 5107   False
# 5108   False
# 5109   False
#
# [5110 rows x 12 columns]

# %% [markdown]
# Appliquer successivement les 3 filtres au sein d'une fonction qui prend en entrée le dataframe, _stroke_, _gender_, _max_age_ et qui renvoie une liste de dictionnaire de patients (utiliser la méthode pandas [to_dict](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_dict.html)).
#
# Exemple
# ```
# [{'id': 9046,
#   'gender': 'Male',
#   'age': 67.0,
#   ...
#   'smoking_status': 'formerly smoked',
#   'stroke': 1},
#  {'id': 31112,
#   'gender': 'Male',
#   'age': 80.0,
#   ...
#   'smoking_status': 'formerly smoked',
#   'stroke': 1}]
#   ```

# %%
def filter_patient(df_value, max_age, gender, stroke):
    df_filtered = df_value[(df_value["age"] <= max_age) & (df_value["gender"] == gender) & (df_value["stroke"] == stroke)]

    return df_filtered.to_dict('records')

filter_patient(df, 80, "Male", 0)
# Out:
# [{'id': 30669,
#   'gender': 'Male',
#   'age': 3.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Children',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 95.12,
#   'bmi': 18.0,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 30468,
#   'gender': 'Male',
#   'age': 58.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 87.96,
#   'bmi': 39.2,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 46136,
#   'gender': 'Male',
#   'age': 14.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Never worked',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 161.28,
#   'bmi': 19.1,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 64908,
#   'gender': 'Male',
#   'age': 79.0,
#   'hypertension': False,
#   'heart_disease': True,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 57.08,
#   'bmi': 22.0,
#   'smoking_status': 'Formerly smoked',
#   'stroke': False},
#  {'id': 25774,
#   'gender': 'Male',
#   'age': 35.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 85.37,
#   'bmi': 33.0,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 4057,
#   'gender': 'Male',
#   'age': 71.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 198.21,
#   'bmi': 27.3,
#   'smoking_status': 'Formerly smoked',
#   'stroke': False},
#  {'id': 67210,
#   'gender': 'Male',
#   'age': 27.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 82.9,
#   'bmi': 25.0,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 45222,
#   'gender': 'Male',
#   'age': 58.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 55.78,
#   'bmi': 27.5,
#   'smoking_status': 'Smokes',
#   'stroke': False},
#  {'id': 26325,
#   'gender': 'Male',
#   'age': 14.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Government job',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 82.34,
#   'bmi': 31.6,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 42203,
#   'gender': 'Male',
#   'age': 59.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 117.92,
#   'bmi': 29.4,
#   'smoking_status': 'Smokes',
#   'stroke': False},
#  {'id': 55680,
#   'gender': 'Male',
#   'age': 13.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Children',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 114.84,
#   'bmi': 18.3,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 11014,
#   'gender': 'Male',
#   'age': 4.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Children',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 79.17,
#   'bmi': 20.0,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 20980,
#   'gender': 'Male',
#   'age': 67.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 190.7,
#   'bmi': 36.0,
#   'smoking_status': 'Formerly smoked',
#   'stroke': False},
#  {'id': 67318,
#   'gender': 'Male',
#   'age': 58.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Government job',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 56.96,
#   'bmi': 26.8,
#   'smoking_status': 'Smokes',
#   'stroke': False},
#  {'id': 28526,
#   'gender': 'Male',
#   'age': 69.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 203.04,
#   'bmi': 33.6,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 7282,
#   'gender': 'Male',
#   'age': 44.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 81.84,
#   'bmi': 25.1,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 18518,
#   'gender': 'Male',
#   'age': 66.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 242.3,
#   'bmi': 35.3,
#   'smoking_status': 'Smokes',
#   'stroke': False},
#  {'id': 41648,
#   'gender': 'Male',
#   'age': 27.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 102.64,
#   'bmi': 26.4,
#   'smoking_status': 'Smokes',
#   'stroke': False},
#  {'id': 49003,
#   'gender': 'Male',
#   'age': 43.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 146.01,
#   'bmi': 31.5,
#   'smoking_status': 'Smokes',
#   'stroke': False},
#  {'id': 42807,
#   'gender': 'Male',
#   'age': 51.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Government job',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 220.49,
#   'bmi': 43.1,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 66174,
#   'gender': 'Male',
#   'age': 46.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 88.19,
#   'bmi': 29.3,
#   'smoking_status': 'Formerly smoked',
#   'stroke': False},
#  {'id': 41940,
#   'gender': 'Male',
#   'age': 57.0,
#   'hypertension': False,
#   'heart_disease': True,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 62.2,
#   'bmi': 31.0,
#   'smoking_status': 'Formerly smoked',
#   'stroke': False},
#  {'id': 72214,
#   'gender': 'Male',
#   'age': 61.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 69.15,
#   'bmi': 27.7,
#   'smoking_status': 'Formerly smoked',
#   'stroke': False},
#  {'id': 22284,
#   'gender': 'Male',
#   'age': 22.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 103.56,
#   'bmi': 25.1,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 39038,
#   'gender': 'Male',
#   'age': 11.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Children',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 79.03,
#   'bmi': 16.5,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 52134,
#   'gender': 'Male',
#   'age': 53.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 90.12,
#   'bmi': 35.4,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 30171,
#   'gender': 'Male',
#   'age': 27.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Government job',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 95.1,
#   'bmi': 24.3,
#   'smoking_status': 'Formerly smoked',
#   'stroke': False},
#  {'id': 4480,
#   'gender': 'Male',
#   'age': 76.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 234.58,
#   'bmi': 34.3,
#   'smoking_status': 'Formerly smoked',
#   'stroke': False},
#  {'id': 65535,
#   'gender': 'Male',
#   'age': 8.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Children',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 78.05,
#   'bmi': 25.7,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 21130,
#   'gender': 'Male',
#   'age': 33.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 229.92,
#   'bmi': 25.9,
#   'smoking_status': 'Smokes',
#   'stroke': False},
#  {'id': 28799,
#   'gender': 'Male',
#   'age': 11.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Children',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 90.69,
#   'bmi': 18.6,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 31091,
#   'gender': 'Male',
#   'age': 34.0,
#   'hypertension': False,
#   'heart_disease': True,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 106.23,
#   'bmi': 32.5,
#   'smoking_status': 'Formerly smoked',
#   'stroke': False},
#  {'id': 45053,
#   'gender': 'Male',
#   'age': 64.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Government job',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 239.64,
#   'bmi': 34.6,
#   'smoking_status': 'Formerly smoked',
#   'stroke': False},
#  {'id': 49713,
#   'gender': 'Male',
#   'age': 68.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 116.23,
#   'bmi': 26.1,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 5973,
#   'gender': 'Male',
#   'age': 43.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 86.78,
#   'bmi': 23.5,
#   'smoking_status': 'Smokes',
#   'stroke': False},
#  {'id': 66333,
#   'gender': 'Male',
#   'age': 52.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 78.4,
#   'bmi': 64.8,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 49916,
#   'gender': 'Male',
#   'age': 76.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 110.99,
#   'bmi': 29.8,
#   'smoking_status': 'Formerly smoked',
#   'stroke': False},
#  {'id': 71038,
#   'gender': 'Male',
#   'age': 34.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 137.96,
#   'bmi': 35.1,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 28286,
#   'gender': 'Male',
#   'age': 44.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 74.91,
#   'bmi': 37.5,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 10159,
#   'gender': 'Male',
#   'age': 41.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 99.8,
#   'bmi': 31.6,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 64489,
#   'gender': 'Male',
#   'age': 56.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Government job',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 73.02,
#   'bmi': 31.1,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 71539,
#   'gender': 'Male',
#   'age': 25.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 138.29,
#   'bmi': 27.3,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 31741,
#   'gender': 'Male',
#   'age': 4.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Children',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 106.22,
#   'bmi': 16.7,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 46527,
#   'gender': 'Male',
#   'age': 53.0,
#   'hypertension': True,
#   'heart_disease': True,
#   'ever_married': True,
#   'work_type': 'Government job',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 109.51,
#   'bmi': 41.9,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 22537,
#   'gender': 'Male',
#   'age': 5.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Children',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 85.84,
#   'bmi': 16.4,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 50611,
#   'gender': 'Male',
#   'age': 4.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Children',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 110.15,
#   'bmi': 17.1,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 63732,
#   'gender': 'Male',
#   'age': 70.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 251.6,
#   'bmi': 27.1,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 9608,
#   'gender': 'Male',
#   'age': 24.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 123.1,
#   'bmi': 37.9,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 10504,
#   'gender': 'Male',
#   'age': 55.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Government job',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 97.4,
#   'bmi': 44.6,
#   'smoking_status': 'Formerly smoked',
#   'stroke': False},
#  {'id': 60148,
#   'gender': 'Male',
#   'age': 34.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 80.81,
#   'bmi': 33.2,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 9637,
#   'gender': 'Male',
#   'age': 26.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 120.31,
#   'bmi': 22.3,
#   'smoking_status': 'Smokes',
#   'stroke': False},
#  {'id': 52173,
#   'gender': 'Male',
#   'age': 38.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 74.09,
#   'bmi': 39.6,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 2374,
#   'gender': 'Male',
#   'age': 60.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 213.37,
#   'bmi': 36.0,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 15528,
#   'gender': 'Male',
#   'age': 58.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 223.36,
#   'bmi': 41.5,
#   'smoking_status': 'Formerly smoked',
#   'stroke': False},
#  {'id': 34608,
#   'gender': 'Male',
#   'age': 57.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 86.67,
#   'bmi': 39.0,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 54975,
#   'gender': 'Male',
#   'age': 7.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 64.06,
#   'bmi': 18.9,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 27213,
#   'gender': 'Male',
#   'age': 64.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 178.29,
#   'bmi': 36.1,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 10913,
#   'gender': 'Male',
#   'age': 12.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Children',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 86.86,
#   'bmi': 25.4,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 20351,
#   'gender': 'Male',
#   'age': 75.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Government job',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 94.29,
#   'bmi': 35.2,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 55351,
#   'gender': 'Male',
#   'age': 63.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 90.07,
#   'bmi': 36.8,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 59729,
#   'gender': 'Male',
#   'age': 53.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 211.03,
#   'bmi': 34.2,
#   'smoking_status': 'Formerly smoked',
#   'stroke': False},
#  {'id': 3655,
#   'gender': 'Male',
#   'age': 31.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Government job',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 91.65,
#   'bmi': 24.6,
#   'smoking_status': 'Formerly smoked',
#   'stroke': False},
#  {'id': 38119,
#   'gender': 'Male',
#   'age': 64.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Government job',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 94.48,
#   'bmi': 31.1,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 67177,
#   'gender': 'Male',
#   'age': 53.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 116.66,
#   'bmi': 28.5,
#   'smoking_status': 'Formerly smoked',
#   'stroke': False},
#  {'id': 58600,
#   'gender': 'Male',
#   'age': 65.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 112.09,
#   'bmi': 29.5,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 65946,
#   'gender': 'Male',
#   'age': 53.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 123.87,
#   'bmi': 28.8,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 61350,
#   'gender': 'Male',
#   'age': 20.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Government job',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 98.7,
#   'bmi': 26.2,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 61465,
#   'gender': 'Male',
#   'age': 13.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Children',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 55.39,
#   'bmi': 23.2,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 18108,
#   'gender': 'Male',
#   'age': 21.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Government job',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 66.07,
#   'bmi': 27.9,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 36471,
#   'gender': 'Male',
#   'age': 65.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 145.15,
#   'bmi': 28.9,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 15689,
#   'gender': 'Male',
#   'age': 42.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Government job',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 68.19,
#   'bmi': 31.0,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 8233,
#   'gender': 'Male',
#   'age': 72.0,
#   'hypertension': False,
#   'heart_disease': True,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 97.53,
#   'bmi': 29.4,
#   'smoking_status': 'Smokes',
#   'stroke': False},
#  {'id': 46436,
#   'gender': 'Male',
#   'age': 13.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Children',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 122.31,
#   'bmi': 15.3,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 23221,
#   'gender': 'Male',
#   'age': 29.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 83.51,
#   'bmi': 37.1,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 31830,
#   'gender': 'Male',
#   'age': 59.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 86.46,
#   'bmi': 30.5,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 7351,
#   'gender': 'Male',
#   'age': 13.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 92.14,
#   'bmi': 23.2,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 66196,
#   'gender': 'Male',
#   'age': 75.0,
#   'hypertension': False,
#   'heart_disease': True,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 201.76,
#   'bmi': 30.2,
#   'smoking_status': 'Formerly smoked',
#   'stroke': False},
#  {'id': 8595,
#   'gender': 'Male',
#   'age': 25.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 95.59,
#   'bmi': 25.1,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 621,
#   'gender': 'Male',
#   'age': 69.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 101.52,
#   'bmi': 26.8,
#   'smoking_status': 'Smokes',
#   'stroke': False},
#  {'id': 5835,
#   'gender': 'Male',
#   'age': 68.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 92.21,
#   'bmi': 27.3,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 46474,
#   'gender': 'Male',
#   'age': 26.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 100.09,
#   'bmi': 27.4,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 63050,
#   'gender': 'Male',
#   'age': 25.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 96.17,
#   'bmi': 22.1,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 22470,
#   'gender': 'Male',
#   'age': 61.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Government job',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 184.15,
#   'bmi': 56.3,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 15649,
#   'gender': 'Male',
#   'age': 54.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 198.69,
#   'bmi': 60.8,
#   'smoking_status': 'Smokes',
#   'stroke': False},
#  {'id': 11974,
#   'gender': 'Male',
#   'age': 11.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Children',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 82.58,
#   'bmi': 25.5,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 41523,
#   'gender': 'Male',
#   'age': 9.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Children',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 94.59,
#   'bmi': 20.0,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 50441,
#   'gender': 'Male',
#   'age': 20.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 104.48,
#   'bmi': 21.7,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 16927,
#   'gender': 'Male',
#   'age': 21.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 98.01,
#   'bmi': 24.2,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 33404,
#   'gender': 'Male',
#   'age': 35.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 89.32,
#   'bmi': 36.7,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 50965,
#   'gender': 'Male',
#   'age': 53.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 65.24,
#   'bmi': 28.9,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 21077,
#   'gender': 'Male',
#   'age': 60.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 80.98,
#   'bmi': 29.7,
#   'smoking_status': 'Formerly smoked',
#   'stroke': False},
#  {'id': 12982,
#   'gender': 'Male',
#   'age': 74.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 186.17,
#   'bmi': 44.3,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 54375,
#   'gender': 'Male',
#   'age': 5.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Children',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 122.19,
#   'bmi': 35.0,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 51112,
#   'gender': 'Male',
#   'age': 29.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 118.7,
#   'bmi': 33.2,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 71238,
#   'gender': 'Male',
#   'age': 52.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 74.64,
#   'bmi': 30.7,
#   'smoking_status': 'Smokes',
#   'stroke': False},
#  {'id': 24892,
#   'gender': 'Male',
#   'age': 64.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 97.08,
#   'bmi': 31.7,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 27757,
#   'gender': 'Male',
#   'age': 31.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 88.78,
#   'bmi': 35.8,
#   'smoking_status': 'Smokes',
#   'stroke': False},
#  {'id': 31279,
#   'gender': 'Male',
#   'age': 22.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 122.1,
#   'bmi': 23.6,
#   'smoking_status': 'Smokes',
#   'stroke': False},
#  {'id': 25099,
#   'gender': 'Male',
#   'age': 41.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Government job',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 74.81,
#   'bmi': 39.7,
#   'smoking_status': 'Smokes',
#   'stroke': False},
#  {'id': 21713,
#   'gender': 'Male',
#   'age': 49.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 102.91,
#   'bmi': 24.7,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 22622,
#   'gender': 'Male',
#   'age': 10.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Children',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 108.79,
#   'bmi': 21.0,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 17242,
#   'gender': 'Male',
#   'age': 67.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 68.52,
#   'bmi': 26.2,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 16380,
#   'gender': 'Male',
#   'age': 40.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 89.77,
#   'bmi': 27.5,
#   'smoking_status': 'Smokes',
#   'stroke': False},
#  {'id': 9729,
#   'gender': 'Male',
#   'age': 70.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 102.64,
#   'bmi': 28.3,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 6855,
#   'gender': 'Male',
#   'age': 72.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 114.01,
#   'bmi': 31.8,
#   'smoking_status': 'Formerly smoked',
#   'stroke': False},
#  {'id': 5374,
#   'gender': 'Male',
#   'age': 23.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 93.74,
#   'bmi': 31.2,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 26028,
#   'gender': 'Male',
#   'age': 51.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 98.41,
#   'bmi': 32.1,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 14712,
#   'gender': 'Male',
#   'age': 57.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 89.44,
#   'bmi': 26.7,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 23094,
#   'gender': 'Male',
#   'age': 65.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 105.61,
#   'bmi': 27.9,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 63606,
#   'gender': 'Male',
#   'age': 29.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Government job',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 60.34,
#   'bmi': 29.6,
#   'smoking_status': 'Formerly smoked',
#   'stroke': False},
#  {'id': 545,
#   'gender': 'Male',
#   'age': 42.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 210.48,
#   'bmi': 71.9,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 36331,
#   'gender': 'Male',
#   'age': 18.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 70.34,
#   'bmi': 24.2,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 42359,
#   'gender': 'Male',
#   'age': 9.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Children',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 122.22,
#   'bmi': 17.7,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 34641,
#   'gender': 'Male',
#   'age': 40.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 100.35,
#   'bmi': 28.1,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 15791,
#   'gender': 'Male',
#   'age': 77.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 193.83,
#   'bmi': 26.5,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 68275,
#   'gender': 'Male',
#   'age': 52.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 247.69,
#   'bmi': 35.1,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 60902,
#   'gender': 'Male',
#   'age': 5.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Children',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 71.43,
#   'bmi': 19.3,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 58439,
#   'gender': 'Male',
#   'age': 36.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 61.29,
#   'bmi': 26.7,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 62936,
#   'gender': 'Male',
#   'age': 46.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 103.62,
#   'bmi': 40.9,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 29010,
#   'gender': 'Male',
#   'age': 5.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Children',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 100.52,
#   'bmi': 17.2,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 44912,
#   'gender': 'Male',
#   'age': 12.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Children',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 67.06,
#   'bmi': 16.1,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 59829,
#   'gender': 'Male',
#   'age': 67.0,
#   'hypertension': False,
#   'heart_disease': True,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 144.1,
#   'bmi': 27.6,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 36942,
#   'gender': 'Male',
#   'age': 27.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 114.79,
#   'bmi': 32.0,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 61697,
#   'gender': 'Male',
#   'age': 25.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 113.8,
#   'bmi': 35.3,
#   'smoking_status': 'Formerly smoked',
#   'stroke': False},
#  {'id': 17148,
#   'gender': 'Male',
#   'age': 57.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 189.57,
#   'bmi': 30.7,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 40448,
#   'gender': 'Male',
#   'age': 54.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 81.26,
#   'bmi': 26.4,
#   'smoking_status': 'Formerly smoked',
#   'stroke': False},
#  {'id': 15095,
#   'gender': 'Male',
#   'age': 18.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 112.17,
#   'bmi': 31.7,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 11960,
#   'gender': 'Male',
#   'age': 45.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 99.97,
#   'bmi': 35.6,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 56179,
#   'gender': 'Male',
#   'age': 29.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 207.58,
#   'bmi': 22.8,
#   'smoking_status': 'Smokes',
#   'stroke': False},
#  {'id': 44315,
#   'gender': 'Male',
#   'age': 18.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 182.86,
#   'bmi': 21.0,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 25483,
#   'gender': 'Male',
#   'age': 72.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 215.64,
#   'bmi': 26.7,
#   'smoking_status': 'Formerly smoked',
#   'stroke': False},
#  {'id': 47732,
#   'gender': 'Male',
#   'age': 5.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Children',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 163.7,
#   'bmi': 18.4,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 53660,
#   'gender': 'Male',
#   'age': 57.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 108.53,
#   'bmi': 19.4,
#   'smoking_status': 'Smokes',
#   'stroke': False},
#  {'id': 56553,
#   'gender': 'Male',
#   'age': 51.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 63.61,
#   'bmi': 42.3,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 30480,
#   'gender': 'Male',
#   'age': 48.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 85.54,
#   'bmi': 32.2,
#   'smoking_status': 'Smokes',
#   'stroke': False},
#  {'id': 31090,
#   'gender': 'Male',
#   'age': 15.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Children',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 205.5,
#   'bmi': 24.2,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 27377,
#   'gender': 'Male',
#   'age': 53.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 79.87,
#   'bmi': 30.9,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 61408,
#   'gender': 'Male',
#   'age': 23.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Never worked',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 125.26,
#   'bmi': 18.7,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 33552,
#   'gender': 'Male',
#   'age': 31.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 114.32,
#   'bmi': 27.7,
#   'smoking_status': 'Smokes',
#   'stroke': False},
#  {'id': 31364,
#   'gender': 'Male',
#   'age': 5.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Children',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 92.23,
#   'bmi': 16.7,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 7446,
#   'gender': 'Male',
#   'age': 44.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 83.51,
#   'bmi': 31.2,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 65130,
#   'gender': 'Male',
#   'age': 40.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 144.48,
#   'bmi': 29.8,
#   'smoking_status': 'Smokes',
#   'stroke': False},
#  {'id': 27794,
#   'gender': 'Male',
#   'age': 7.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Children',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 88.39,
#   'bmi': 19.7,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 30753,
#   'gender': 'Male',
#   'age': 42.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Government job',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 93.79,
#   'bmi': 27.2,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 46809,
#   'gender': 'Male',
#   'age': 48.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 147.14,
#   'bmi': 22.3,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 71533,
#   'gender': 'Male',
#   'age': 50.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 158.31,
#   'bmi': 32.8,
#   'smoking_status': 'Formerly smoked',
#   'stroke': False},
#  {'id': 35565,
#   'gender': 'Male',
#   'age': 43.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 111.43,
#   'bmi': 21.9,
#   'smoking_status': 'Smokes',
#   'stroke': False},
#  {'id': 34558,
#   'gender': 'Male',
#   'age': 33.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 219.97,
#   'bmi': 39.6,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 38987,
#   'gender': 'Male',
#   'age': 65.0,
#   'hypertension': False,
#   'heart_disease': True,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 58.37,
#   'bmi': 28.0,
#   'smoking_status': 'Smokes',
#   'stroke': False},
#  {'id': 5353,
#   'gender': 'Male',
#   'age': 52.0,
#   'hypertension': False,
#   'heart_disease': True,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 101.5,
#   'bmi': 31.2,
#   'smoking_status': 'Smokes',
#   'stroke': False},
#  {'id': 13517,
#   'gender': 'Male',
#   'age': 59.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 100.54,
#   'bmi': 35.8,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 36355,
#   'gender': 'Male',
#   'age': 58.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Government job',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 111.73,
#   'bmi': 34.6,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 2532,
#   'gender': 'Male',
#   'age': 28.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 85.79,
#   'bmi': 26.7,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 52512,
#   'gender': 'Male',
#   'age': 57.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 98.54,
#   'bmi': 30.2,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 5545,
#   'gender': 'Male',
#   'age': 48.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 99.67,
#   'bmi': 23.3,
#   'smoking_status': 'Formerly smoked',
#   'stroke': False},
#  {'id': 63693,
#   'gender': 'Male',
#   'age': 37.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 67.39,
#   'bmi': 35.6,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 23650,
#   'gender': 'Male',
#   'age': 15.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Children',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 85.06,
#   'bmi': 21.6,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 53515,
#   'gender': 'Male',
#   'age': 61.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 214.05,
#   'bmi': 29.4,
#   'smoking_status': 'Formerly smoked',
#   'stroke': False},
#  {'id': 11068,
#   'gender': 'Male',
#   'age': 53.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 76.36,
#   'bmi': 29.8,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 48265,
#   'gender': 'Male',
#   'age': 65.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Government job',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 111.85,
#   'bmi': 26.7,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 12662,
#   'gender': 'Male',
#   'age': 74.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 112.54,
#   'bmi': 27.7,
#   'smoking_status': 'Formerly smoked',
#   'stroke': False},
#  {'id': 30567,
#   'gender': 'Male',
#   'age': 71.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 94.65,
#   'bmi': 25.3,
#   'smoking_status': 'Formerly smoked',
#   'stroke': False},
#  {'id': 50491,
#   'gender': 'Male',
#   'age': 78.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 55.32,
#   'bmi': 29.6,
#   'smoking_status': 'Smokes',
#   'stroke': False},
#  {'id': 61013,
#   'gender': 'Male',
#   'age': 52.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 69.37,
#   'bmi': 36.2,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 23551,
#   'gender': 'Male',
#   'age': 28.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 87.43,
#   'bmi': 55.7,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 12738,
#   'gender': 'Male',
#   'age': 56.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 81.18,
#   'bmi': 26.9,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 16615,
#   'gender': 'Male',
#   'age': 76.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 69.61,
#   'bmi': 35.3,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 62999,
#   'gender': 'Male',
#   'age': 10.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Children',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 59.49,
#   'bmi': 18.3,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 66184,
#   'gender': 'Male',
#   'age': 40.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Government job',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 100.26,
#   'bmi': 26.0,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 967,
#   'gender': 'Male',
#   'age': 61.0,
#   'hypertension': False,
#   'heart_disease': True,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 88.27,
#   'bmi': 27.0,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 22870,
#   'gender': 'Male',
#   'age': 12.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Children',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 76.26,
#   'bmi': 20.5,
# ...
#   'hypertension': True,
#   'heart_disease': True,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 221.43,
#   'bmi': 32.5,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 52593,
#   'gender': 'Male',
#   'age': 78.0,
#   'hypertension': False,
#   'heart_disease': True,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 145.03,
#   'bmi': 26.8,
#   'smoking_status': 'Formerly smoked',
#   'stroke': False},
#  {'id': 45469,
#   'gender': 'Male',
#   'age': 16.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Children',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 134.23,
#   'bmi': 30.6,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 41284,
#   'gender': 'Male',
#   'age': 4.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Children',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 62.48,
#   'bmi': 19.9,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 20112,
#   'gender': 'Male',
#   'age': 79.0,
#   'hypertension': False,
#   'heart_disease': True,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 213.38,
#   'bmi': 65.3,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 45627,
#   'gender': 'Male',
#   'age': 60.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 70.52,
#   'bmi': 26.5,
#   'smoking_status': 'Formerly smoked',
#   'stroke': False},
#  {'id': 31660,
#   'gender': 'Male',
#   'age': 23.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 82.39,
#   'bmi': 31.8,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 36196,
#   'gender': 'Male',
#   'age': 21.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 88.29,
#   'bmi': 36.6,
#   'smoking_status': 'Smokes',
#   'stroke': False},
#  {'id': 8341,
#   'gender': 'Male',
#   'age': 10.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Children',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 84.02,
#   'bmi': 18.7,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 14372,
#   'gender': 'Male',
#   'age': 50.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 192.16,
#   'bmi': 43.6,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 61252,
#   'gender': 'Male',
#   'age': 79.0,
#   'hypertension': False,
#   'heart_disease': True,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 82.27,
#   'bmi': 25.2,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 15251,
#   'gender': 'Male',
#   'age': 14.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Children',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 101.87,
#   'bmi': 20.3,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 10416,
#   'gender': 'Male',
#   'age': 71.0,
#   'hypertension': False,
#   'heart_disease': True,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 215.72,
#   'bmi': 39.2,
#   'smoking_status': 'Smokes',
#   'stroke': False},
#  {'id': 7476,
#   'gender': 'Male',
#   'age': 32.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Government job',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 91.93,
#   'bmi': 30.2,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 55526,
#   'gender': 'Male',
#   'age': 46.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Government job',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 58.63,
#   'bmi': 35.3,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 452,
#   'gender': 'Male',
#   'age': 48.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 173.14,
#   'bmi': 37.0,
#   'smoking_status': 'Smokes',
#   'stroke': False},
#  {'id': 38541,
#   'gender': 'Male',
#   'age': 55.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 84.44,
#   'bmi': 30.5,
#   'smoking_status': 'Formerly smoked',
#   'stroke': False},
#  {'id': 18790,
#   'gender': 'Male',
#   'age': 25.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 85.96,
#   'bmi': 34.5,
#   'smoking_status': 'Formerly smoked',
#   'stroke': False},
#  {'id': 45751,
#   'gender': 'Male',
#   'age': 73.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 202.57,
#   'bmi': 37.4,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 52826,
#   'gender': 'Male',
#   'age': 60.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 62.6,
#   'bmi': 30.4,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 42556,
#   'gender': 'Male',
#   'age': 27.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 150.1,
#   'bmi': 25.3,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 56746,
#   'gender': 'Male',
#   'age': 46.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 65.5,
#   'bmi': 30.7,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 65481,
#   'gender': 'Male',
#   'age': 57.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 90.4,
#   'bmi': 26.5,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 68224,
#   'gender': 'Male',
#   'age': 54.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 209.5,
#   'bmi': 37.9,
#   'smoking_status': 'Formerly smoked',
#   'stroke': False},
#  {'id': 61559,
#   'gender': 'Male',
#   'age': 7.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Children',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 86.6,
#   'bmi': 17.1,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 18890,
#   'gender': 'Male',
#   'age': 69.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 87.93,
#   'bmi': 33.6,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 58936,
#   'gender': 'Male',
#   'age': 59.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 203.16,
#   'bmi': 43.4,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 68138,
#   'gender': 'Male',
#   'age': 49.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 92.02,
#   'bmi': 38.1,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 39683,
#   'gender': 'Male',
#   'age': 26.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 71.26,
#   'bmi': 28.6,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 49903,
#   'gender': 'Male',
#   'age': 27.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 72.61,
#   'bmi': 38.5,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 68382,
#   'gender': 'Male',
#   'age': 0.32,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Children',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 127.78,
#   'bmi': 20.8,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 69510,
#   'gender': 'Male',
#   'age': 39.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 121.32,
#   'bmi': 26.8,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 1924,
#   'gender': 'Male',
#   'age': 54.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 74.06,
#   'bmi': 22.6,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 48303,
#   'gender': 'Male',
#   'age': 39.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 71.3,
#   'bmi': 34.7,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 31473,
#   'gender': 'Male',
#   'age': 6.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Children',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 79.05,
#   'bmi': 17.9,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 2573,
#   'gender': 'Male',
#   'age': 56.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Government job',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 84.58,
#   'bmi': 34.5,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 60683,
#   'gender': 'Male',
#   'age': 53.0,
#   'hypertension': False,
#   'heart_disease': True,
#   'ever_married': True,
#   'work_type': 'Government job',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 77.3,
#   'bmi': 33.4,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 70537,
#   'gender': 'Male',
#   'age': 5.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Children',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 74.79,
#   'bmi': 19.4,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 12228,
#   'gender': 'Male',
#   'age': 13.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Children',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 97.97,
#   'bmi': 24.5,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 18752,
#   'gender': 'Male',
#   'age': 60.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 87.86,
#   'bmi': 29.0,
#   'smoking_status': 'Formerly smoked',
#   'stroke': False},
#  {'id': 35152,
#   'gender': 'Male',
#   'age': 10.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Children',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 76.92,
#   'bmi': 15.8,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 70081,
#   'gender': 'Male',
#   'age': 42.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 77.24,
#   'bmi': 41.2,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 72340,
#   'gender': 'Male',
#   'age': 21.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 120.94,
#   'bmi': 29.7,
#   'smoking_status': 'Formerly smoked',
#   'stroke': False},
#  {'id': 42323,
#   'gender': 'Male',
#   'age': 59.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Government job',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 231.95,
#   'bmi': 33.2,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 49972,
#   'gender': 'Male',
#   'age': 63.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 216.38,
#   'bmi': 34.5,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 44142,
#   'gender': 'Male',
#   'age': 25.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 95.01,
#   'bmi': 28.0,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 12753,
#   'gender': 'Male',
#   'age': 53.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 86.25,
#   'bmi': 29.3,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 30824,
#   'gender': 'Male',
#   'age': 12.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Children',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 115.47,
#   'bmi': 22.6,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 47196,
#   'gender': 'Male',
#   'age': 42.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 110.68,
#   'bmi': 32.4,
#   'smoking_status': 'Formerly smoked',
#   'stroke': False},
#  {'id': 23488,
#   'gender': 'Male',
#   'age': 80.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 213.33,
#   'bmi': 31.1,
#   'smoking_status': 'Formerly smoked',
#   'stroke': False},
#  {'id': 2849,
#   'gender': 'Male',
#   'age': 32.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 93.52,
#   'bmi': 31.9,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 13116,
#   'gender': 'Male',
#   'age': 49.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 87.06,
#   'bmi': 28.3,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 48146,
#   'gender': 'Male',
#   'age': 70.0,
#   'hypertension': False,
#   'heart_disease': True,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 93.02,
#   'bmi': 40.2,
#   'smoking_status': 'Formerly smoked',
#   'stroke': False},
#  {'id': 20070,
#   'gender': 'Male',
#   'age': 23.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 86.7,
#   'bmi': 24.6,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 2005,
#   'gender': 'Male',
#   'age': 78.0,
#   'hypertension': False,
#   'heart_disease': True,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 169.43,
#   'bmi': 23.5,
#   'smoking_status': 'Formerly smoked',
#   'stroke': False},
#  {'id': 50541,
#   'gender': 'Male',
#   'age': 47.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Government job',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 73.48,
#   'bmi': 34.9,
#   'smoking_status': 'Smokes',
#   'stroke': False},
#  {'id': 66264,
#   'gender': 'Male',
#   'age': 29.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Government job',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 102.4,
#   'bmi': 26.9,
#   'smoking_status': 'Smokes',
#   'stroke': False},
#  ...]

# %% [markdown]
# A présent on souhaite ajouter des informations sur les types des paramètres et valeurs de retour de la fonction pour faciliter sa compréhension et son utilisation, ce qu’on appelle l’annotation de type (type hinting).
#
# Cette pratique facilite la lecture et la maintenance du code.
#
# Quels changements pour la fonction ?
#
# A la suite de chaque paramètre, on ajoute le type attendu pour le paramètre. À la suite des paramètres on ajoute le type de ce que qui est retourné par la fonction, dans l'exemple ici :
#
# ```def filter_patient(stroke_data_df: pd.DataFrame, gender: str, etc) -> list[dict]```
#
# Ajouter les types dans la définition de la fonction.

# %% [markdown]
# Tester la fonction en ne mettant pas de valeur pour *max_age*.
#
# Que se passe-t-il ?

# %%
def filter_patient(df_value:pd.DataFrame, max_age, gender:str, stroke:bool):
    
    df_filtered = df_value[(df_value["age"] <= max_age) & 
                        (df_value["gender"] == gender) & 
                        (df_value["stroke"] == stroke)]

    return df_filtered.to_dict('records')

filter_patient(df, gender="Female", stroke=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 9
#       3     df_filtered = df_value[(df_value["age"] <= max_age) &
#       4                         (df_value["gender"] == gender) &
#       5                         (df_value["stroke"] == stroke)]
#       7     return df_filtered.to_dict('records')
# ----> 9 filter_patient(df, gender="Female", stroke=True)
#
# TypeError: filter_patient() missing 1 required positional argument: 'max_age'

# %% [markdown]
# Dans la fonction écrite ci-dessus, chaque paramètre est obligatoire.
#
# On souhaite pouvoir filtrer les patients sur 0, 1 ou 2 des paramètres de la fonction (filtrer seulement sur *max_age*  mais ne pas appliquer de filtres sur _gender_ et _stroke_ par exemple).
#
# On peut rendre optionnel les paramètres d'un fonction en choisissant une valeur par défault. Si on utilise la fonction en n'utilisant pas ces paramètres alors la valeur par défault est utilisé.
#
# Copier coller votre fonction ci-dessous et ajouter en paramètre : `max_age=None`
#
# et ajouter la condition suivante **avant le filtre** sur `max_age` :
#
# ```if max_age is not None : ```
#
# Si la fonction _filter_patient_ est appelée sans argument *max_age*, alors le filtre sur *max_age* n'est pas appliqué.
#
# Il est tout à fait possible de définir une valeur par défault par exemple 30 ans : dans ce cas si la fonction est appelée sans argument *max_age*, alors par défault on filtre les patients ayant moins de 30 ans.
#
# **ATTENTION :** Les paramètres optionnels doivent toujours être à la fin de la liste de paramètres.

# %%
# fonction filter_patient paramètre max_age optionnel
def filter_patient(df_value:pd.DataFrame, gender:str, stroke:bool, max_age:int=None):
    
    if max_age is not None :
        df_filtered = df_value.loc[(df_value["age"] <= max_age) & (df_value["gender"] == gender) & (df_value["stroke"] == stroke)]
        return df_filtered.to_dict('records')
    else:
        df_filtered = df_value.loc[(df_value["gender"] == gender) & (df_value["stroke"] == stroke)]
        return df_filtered.to_dict('records')

# %%
# test fonction sans argument max_age
filter_patient(df, gender="Female", stroke=True)
# Out:
# [{'id': 51676,
#   'gender': 'Female',
#   'age': 61.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 202.21,
#   'bmi': 61.8,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 60182,
#   'gender': 'Female',
#   'age': 49.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 171.23,
#   'bmi': 34.4,
#   'smoking_status': 'Smokes',
#   'stroke': True},
#  {'id': 1665,
#   'gender': 'Female',
#   'age': 79.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 174.12,
#   'bmi': 24.0,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 10434,
#   'gender': 'Female',
#   'age': 69.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 94.39,
#   'bmi': 22.8,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 27419,
#   'gender': 'Female',
#   'age': 59.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 76.15,
#   'bmi': 23.3,
#   'smoking_status': 'Unknown',
#   'stroke': True},
#  {'id': 60491,
#   'gender': 'Female',
#   'age': 78.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 58.57,
#   'bmi': 24.2,
#   'smoking_status': 'Unknown',
#   'stroke': True},
#  {'id': 12109,
#   'gender': 'Female',
#   'age': 81.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 80.43,
#   'bmi': 29.7,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 12095,
#   'gender': 'Female',
#   'age': 61.0,
#   'hypertension': False,
#   'heart_disease': True,
#   'ever_married': True,
#   'work_type': 'Government job',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 120.46,
#   'bmi': 36.8,
#   'smoking_status': 'Smokes',
#   'stroke': True},
#  {'id': 12175,
#   'gender': 'Female',
#   'age': 54.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 104.51,
#   'bmi': 27.3,
#   'smoking_status': 'Smokes',
#   'stroke': True},
#  {'id': 5317,
#   'gender': 'Female',
#   'age': 79.0,
#   'hypertension': False,
#   'heart_disease': True,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 214.09,
#   'bmi': 28.2,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 58202,
#   'gender': 'Female',
#   'age': 50.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 167.41,
#   'bmi': 30.9,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 27458,
#   'gender': 'Female',
#   'age': 60.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 89.22,
#   'bmi': 37.8,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 70630,
#   'gender': 'Female',
#   'age': 71.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Government job',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 193.94,
#   'bmi': 22.4,
#   'smoking_status': 'Smokes',
#   'stroke': True},
#  {'id': 13861,
#   'gender': 'Female',
#   'age': 52.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 233.29,
#   'bmi': 48.9,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 68794,
#   'gender': 'Female',
#   'age': 79.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 228.7,
#   'bmi': 26.6,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 38047,
#   'gender': 'Female',
#   'age': 65.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 100.98,
#   'bmi': 28.2,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 39373,
#   'gender': 'Female',
#   'age': 82.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 196.92,
#   'bmi': 22.2,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 712,
#   'gender': 'Female',
#   'age': 82.0,
#   'hypertension': True,
#   'heart_disease': True,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 84.03,
#   'bmi': 26.5,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 24977,
#   'gender': 'Female',
#   'age': 72.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 74.63,
#   'bmi': 23.1,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 62602,
#   'gender': 'Female',
#   'age': 49.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 60.91,
#   'bmi': 29.9,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 1845,
#   'gender': 'Female',
#   'age': 63.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 90.9,
#   'bmi': 27.8,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 37937,
#   'gender': 'Female',
#   'age': 75.0,
#   'hypertension': False,
#   'heart_disease': True,
#   'ever_married': False,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 109.78,
#   'bmi': 33.6,
#   'smoking_status': 'Unknown',
#   'stroke': True},
#  {'id': 47472,
#   'gender': 'Female',
#   'age': 58.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 107.26,
#   'bmi': 38.6,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 36338,
#   'gender': 'Female',
#   'age': 39.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 58.09,
#   'bmi': 39.2,
#   'smoking_status': 'Smokes',
#   'stroke': True},
#  {'id': 18587,
#   'gender': 'Female',
#   'age': 76.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 89.96,
#   'bmi': 27.5,
#   'smoking_status': 'Unknown',
#   'stroke': True},
#  {'id': 59190,
#   'gender': 'Female',
#   'age': 79.0,
#   'hypertension': False,
#   'heart_disease': True,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 127.29,
#   'bmi': 27.7,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 47167,
#   'gender': 'Female',
#   'age': 77.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 124.13,
#   'bmi': 31.4,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 8752,
#   'gender': 'Female',
#   'age': 63.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Government job',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 197.54,
#   'bmi': 60.4,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 38829,
#   'gender': 'Female',
#   'age': 82.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 59.32,
#   'bmi': 33.2,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 5111,
#   'gender': 'Female',
#   'age': 54.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Government job',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 180.93,
#   'bmi': 27.7,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 10710,
#   'gender': 'Female',
#   'age': 56.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 185.17,
#   'bmi': 40.4,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 55927,
#   'gender': 'Female',
#   'age': 80.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 74.9,
#   'bmi': 22.2,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 65842,
#   'gender': 'Female',
#   'age': 67.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 61.94,
#   'bmi': 25.3,
#   'smoking_status': 'Smokes',
#   'stroke': True},
#  {'id': 19557,
#   'gender': 'Female',
#   'age': 45.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 93.72,
#   'bmi': 30.2,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 17004,
#   'gender': 'Female',
#   'age': 70.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 221.58,
#   'bmi': 47.5,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 7371,
#   'gender': 'Female',
#   'age': 80.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 72.67,
#   'bmi': 28.9,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 70676,
#   'gender': 'Female',
#   'age': 76.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Government job',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 62.57,
#   'bmi': 19.1,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 2326,
#   'gender': 'Female',
#   'age': 67.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 179.12,
#   'bmi': 28.1,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 27169,
#   'gender': 'Female',
#   'age': 66.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Government job',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 116.55,
#   'bmi': 31.1,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 19773,
#   'gender': 'Female',
#   'age': 52.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 96.59,
#   'bmi': 26.4,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 66159,
#   'gender': 'Female',
#   'age': 80.0,
#   'hypertension': False,
#   'heart_disease': True,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 66.72,
#   'bmi': 21.7,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 71673,
#   'gender': 'Female',
#   'age': 79.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 110.85,
#   'bmi': 24.1,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 45805,
#   'gender': 'Female',
#   'age': 51.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 165.31,
#   'bmi': 50.6,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 26015,
#   'gender': 'Female',
#   'age': 66.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 101.45,
#   'bmi': 31.0,
#   'smoking_status': 'Unknown',
#   'stroke': True},
#  {'id': 26727,
#   'gender': 'Female',
#   'age': 79.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 88.92,
#   'bmi': 22.9,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 66638,
#   'gender': 'Female',
#   'age': 68.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 79.79,
#   'bmi': 29.7,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 71796,
#   'gender': 'Female',
#   'age': 70.0,
#   'hypertension': False,
#   'heart_disease': True,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 59.35,
#   'bmi': 32.3,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 28291,
#   'gender': 'Female',
#   'age': 79.0,
#   'hypertension': False,
#   'heart_disease': True,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 226.98,
#   'bmi': 29.8,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 66315,
#   'gender': 'Female',
#   'age': 57.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 68.02,
#   'bmi': 37.5,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 37726,
#   'gender': 'Female',
#   'age': 80.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 68.56,
#   'bmi': 26.2,
#   'smoking_status': 'Unknown',
#   'stroke': True},
#  {'id': 2458,
#   'gender': 'Female',
#   'age': 78.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 235.63,
#   'bmi': 32.3,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 35512,
#   'gender': 'Female',
#   'age': 70.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 76.34,
#   'bmi': 24.4,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 4639,
#   'gender': 'Female',
#   'age': 69.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Government job',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 82.81,
#   'bmi': 28.0,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 63973,
#   'gender': 'Female',
#   'age': 77.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Government job',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 190.32,
#   'bmi': 31.4,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 45277,
#   'gender': 'Female',
#   'age': 74.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 231.61,
#   'bmi': 34.6,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 4712,
#   'gender': 'Female',
#   'age': 81.0,
#   'hypertension': False,
#   'heart_disease': True,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 78.7,
#   'bmi': 19.4,
#   'smoking_status': 'Unknown',
#   'stroke': True},
#  {'id': 33175,
#   'gender': 'Female',
#   'age': 57.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Government job',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 110.52,
#   'bmi': 28.5,
#   'smoking_status': 'Unknown',
#   'stroke': True},
#  {'id': 42072,
#   'gender': 'Female',
#   'age': 50.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 73.18,
#   'bmi': 30.3,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 12062,
#   'gender': 'Female',
#   'age': 54.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 191.82,
#   'bmi': 40.4,
#   'smoking_status': 'Smokes',
#   'stroke': True},
#  {'id': 30456,
#   'gender': 'Female',
#   'age': 79.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 93.05,
#   'bmi': 24.2,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 59125,
#   'gender': 'Female',
#   'age': 53.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Government job',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 64.17,
#   'bmi': 41.5,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 36706,
#   'gender': 'Female',
#   'age': 76.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 106.41,
#   'bmi': 32.5,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 41069,
#   'gender': 'Female',
#   'age': 45.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 224.1,
#   'bmi': 56.6,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 71639,
#   'gender': 'Female',
#   'age': 68.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Government job',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 82.1,
#   'bmi': 27.1,
#   'smoking_status': 'Unknown',
#   'stroke': True},
#  {'id': 31720,
#   'gender': 'Female',
#   'age': 38.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 82.28,
#   'bmi': 24.0,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 5563,
#   'gender': 'Female',
#   'age': 77.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 105.22,
#   'bmi': 31.0,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 68798,
#   'gender': 'Female',
#   'age': 58.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 59.86,
#   'bmi': 28.0,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 72918,
#   'gender': 'Female',
#   'age': 53.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 62.55,
#   'bmi': 30.3,
#   'smoking_status': 'Unknown',
#   'stroke': True},
#  {'id': 14164,
#   'gender': 'Female',
#   'age': 72.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 219.91,
#   'bmi': 67.3,
#   'smoking_status': 'Unknown',
#   'stroke': True},
#  {'id': 50522,
#   'gender': 'Female',
#   'age': 72.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Government job',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 131.41,
#   'bmi': 28.4,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 70943,
#   'gender': 'Female',
#   'age': 80.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 73.54,
#   'bmi': 24.0,
#   'smoking_status': 'Unknown',
#   'stroke': True},
#  {'id': 48796,
#   'gender': 'Female',
#   'age': 75.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Government job',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 62.48,
#   'bmi': 19.1,
#   'smoking_status': 'Unknown',
#   'stroke': True},
#  {'id': 53440,
#   'gender': 'Female',
#   'age': 73.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 190.14,
#   'bmi': 36.5,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 16817,
#   'gender': 'Female',
#   'age': 78.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 130.54,
#   'bmi': 20.1,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 31563,
#   'gender': 'Female',
#   'age': 38.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 101.45,
#   'bmi': 31.0,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 20387,
#   'gender': 'Female',
#   'age': 68.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 206.09,
#   'bmi': 26.7,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 71279,
#   'gender': 'Female',
#   'age': 71.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Government job',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 263.32,
#   'bmi': 38.7,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 11762,
#   'gender': 'Female',
#   'age': 76.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 207.28,
#   'bmi': 34.9,
#   'smoking_status': 'Unknown',
#   'stroke': True},
#  {'id': 30683,
#   'gender': 'Female',
#   'age': 75.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 199.2,
#   'bmi': 26.6,
#   'smoking_status': 'Unknown',
#   'stroke': True},
#  {'id': 45965,
#   'gender': 'Female',
#   'age': 59.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 116.44,
#   'bmi': 23.8,
#   'smoking_status': 'Smokes',
#   'stroke': True},
#  {'id': 8045,
#   'gender': 'Female',
#   'age': 74.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 70.28,
#   'bmi': 21.8,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 37651,
#   'gender': 'Female',
#   'age': 69.0,
#   'hypertension': True,
#   'heart_disease': True,
#   'ever_married': False,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 72.17,
#   'bmi': 36.8,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 17308,
#   'gender': 'Female',
#   'age': 72.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 221.79,
#   'bmi': 30.0,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 62861,
#   'gender': 'Female',
#   'age': 78.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 67.29,
#   'bmi': 24.6,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 72081,
#   'gender': 'Female',
#   'age': 57.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Government job',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 67.41,
#   'bmi': 32.9,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 58978,
#   'gender': 'Female',
#   'age': 70.0,
#   'hypertension': False,
#   'heart_disease': True,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 239.07,
#   'bmi': 26.1,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 11933,
#   'gender': 'Female',
#   'age': 79.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 169.67,
#   'bmi': 51.9,
#   'smoking_status': 'Unknown',
#   'stroke': True},
#  {'id': 32503,
#   'gender': 'Female',
#   'age': 80.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 76.57,
#   'bmi': 34.1,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 56939,
#   'gender': 'Female',
#   'age': 55.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 92.98,
#   'bmi': 25.6,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 24669,
#   'gender': 'Female',
#   'age': 77.0,
#   'hypertension': False,
#   'heart_disease': True,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 231.56,
#   'bmi': 36.9,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 43054,
#   'gender': 'Female',
#   'age': 50.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 102.16,
#   'bmi': 31.4,
#   'smoking_status': 'Smokes',
#   'stroke': True},
#  {'id': 59437,
#   'gender': 'Female',
#   'age': 57.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 221.89,
#   'bmi': 37.3,
#   'smoking_status': 'Smokes',
#   'stroke': True},
#  {'id': 66258,
#   'gender': 'Female',
#   'age': 71.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 195.71,
#   'bmi': 34.1,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 34567,
#   'gender': 'Female',
#   'age': 81.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 74.02,
#   'bmi': 25.0,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 50931,
#   'gender': 'Female',
#   'age': 76.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 57.92,
#   'bmi': 17.7,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 69768,
#   'gender': 'Female',
#   'age': 1.32,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Children',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 70.37,
#   'bmi': 21.5,
#   'smoking_status': 'Unknown',
#   'stroke': True},
#  {'id': 20426,
#   'gender': 'Female',
#   'age': 78.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 203.87,
#   'bmi': 45.7,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 3512,
#   'gender': 'Female',
#   'age': 70.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 89.13,
#   'bmi': 34.2,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 63453,
#   'gender': 'Female',
#   'age': 56.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Government job',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 162.23,
#   'bmi': 27.3,
#   'smoking_status': 'Unknown',
#   'stroke': True},
#  {'id': 44993,
#   'gender': 'Female',
#   'age': 79.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Government job',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 98.02,
#   'bmi': 22.3,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 60739,
#   'gender': 'Female',
#   'age': 79.0,
#   'hypertension': True,
#   'heart_disease': True,
#   'ever_married': False,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 60.94,
#   'bmi': 18.6,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 67432,
#   'gender': 'Female',
#   'age': 60.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 97.43,
#   'bmi': 26.4,
#   'smoking_status': 'Smokes',
#   'stroke': True},
#  {'id': 2182,
#   'gender': 'Female',
#   'age': 80.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 91.02,
#   'bmi': 32.9,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 40899,
#   'gender': 'Female',
#   'age': 78.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 60.67,
#   'bmi': 18.6,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 62466,
#   'gender': 'Female',
#   'age': 80.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 64.44,
#   'bmi': 45.0,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 33486,
#   'gender': 'Female',
#   'age': 80.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Government job',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 110.66,
#   'bmi': 33.8,
#   'smoking_status': 'Unknown',
#   'stroke': True},
#  {'id': 54567,
#   'gender': 'Female',
#   'age': 46.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 78.18,
#   'bmi': 30.8,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 39912,
#   'gender': 'Female',
#   'age': 32.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 76.13,
#   'bmi': 29.9,
#   'smoking_status': 'Smokes',
#   'stroke': True},
#  {'id': 8003,
#   'gender': 'Female',
#   'age': 77.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 81.32,
#   'bmi': 24.9,
#   'smoking_status': 'Unknown',
#   'stroke': True},
#  {'id': 67895,
#   'gender': 'Female',
#   'age': 82.0,
#   'hypertension': True,
#   'heart_disease': True,
#   'ever_married': True,
#   'work_type': 'Government job',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 215.94,
#   'bmi': 27.9,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 24905,
#   'gender': 'Female',
#   'age': 65.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 205.77,
#   'bmi': 46.0,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 23410,
#   'gender': 'Female',
#   'age': 72.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 97.92,
#   'bmi': 26.9,
#   'smoking_status': 'Smokes',
#   'stroke': True},
#  {'id': 491,
#   'gender': 'Female',
#   'age': 74.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 74.96,
#   'bmi': 26.6,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 8580,
#   'gender': 'Female',
#   'age': 77.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 90.0,
#   'bmi': 32.0,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 28484,
#   'gender': 'Female',
#   'age': 78.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 109.47,
#   'bmi': 30.8,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 51314,
#   'gender': 'Female',
#   'age': 78.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 106.74,
#   'bmi': 33.0,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 37060,
#   'gender': 'Female',
#   'age': 81.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 80.13,
#   'bmi': 23.4,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 33454,
#   'gender': 'Female',
#   'age': 63.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Government job',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 106.58,
#   'bmi': 23.9,
#   'smoking_status': 'Unknown',
#   'stroke': True},
#  {'id': 33943,
#   'gender': 'Female',
#   'age': 39.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 83.24,
#   'bmi': 26.3,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 62439,
#   'gender': 'Female',
#   'age': 51.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Government job',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 103.43,
#   'bmi': 27.3,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 66866,
#   'gender': 'Female',
#   'age': 48.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 74.11,
#   'bmi': 20.5,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 2548,
#   'gender': 'Female',
#   'age': 81.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 95.84,
#   'bmi': 21.5,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 68025,
#   'gender': 'Female',
#   'age': 79.0,
#   'hypertension': False,
#   'heart_disease': True,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 205.33,
#   'bmi': 31.0,
#   'smoking_status': 'Smokes',
#   'stroke': True},
#  {'id': 29552,
#   'gender': 'Female',
#   'age': 55.0,
#   'hypertension': True,
#   'heart_disease': True,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 210.4,
#   'bmi': 40.0,
#   'smoking_status': 'Smokes',
#   'stroke': True},
#  {'id': 25904,
#   'gender': 'Female',
#   'age': 76.0,
#   'hypertension': True,
#   'heart_disease': True,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 199.86,
#   'bmi': 61.1,
#   'smoking_status': 'Smokes',
#   'stroke': True},
#  {'id': 12689,
#   'gender': 'Female',
#   'age': 63.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Government job',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 205.35,
#   'bmi': 42.2,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 54724,
#   'gender': 'Female',
#   'age': 81.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Government job',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 70.3,
#   'bmi': 25.8,
#   'smoking_status': 'Smokes',
#   'stroke': True},
#  {'id': 39186,
#   'gender': 'Female',
#   'age': 57.0,
#   'hypertension': False,
#   'heart_disease': True,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 216.58,
#   'bmi': 31.0,
#   'smoking_status': 'Unknown',
#   'stroke': True},
#  {'id': 32729,
#   'gender': 'Female',
#   'age': 81.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 184.4,
#   'bmi': 27.5,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 31154,
#   'gender': 'Female',
#   'age': 39.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 97.76,
#   'bmi': 29.6,
#   'smoking_status': 'Smokes',
#   'stroke': True},
#  {'id': 69959,
#   'gender': 'Female',
#   'age': 80.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 66.03,
#   'bmi': 35.4,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 10552,
#   'gender': 'Female',
#   'age': 81.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 81.95,
#   'bmi': 16.9,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 12917,
#   'gender': 'Female',
#   'age': 79.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 97.73,
#   'bmi': 21.5,
#   'smoking_status': 'Smokes',
#   'stroke': True},
#  {'id': 68356,
#   'gender': 'Female',
#   'age': 73.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 70.94,
#   'bmi': 34.4,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 23368,
#   'gender': 'Female',
#   'age': 77.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 199.84,
#   'bmi': 28.0,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 1210,
#   'gender': 'Female',
#   'age': 68.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 211.06,
#   'bmi': 39.3,
#   'smoking_status': 'Unknown',
#   'stroke': True},
#  {'id': 1836,
#   'gender': 'Female',
#   'age': 51.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 88.2,
#   'bmi': 28.4,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 40460,
#   'gender': 'Female',
#   'age': 68.0,
#   'hypertension': True,
#   'heart_disease': True,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 247.51,
#   'bmi': 40.5,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 49669,
#   'gender': 'Female',
#   'age': 14.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Children',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 57.93,
#   'bmi': 30.9,
#   'smoking_status': 'Unknown',
#   'stroke': True},
#  {'id': 27153,
#   'gender': 'Female',
#   'age': 75.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 78.8,
#   'bmi': 29.3,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 43424,
#   'gender': 'Female',
#   'age': 78.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 78.81,
#   'bmi': 19.6,
#   'smoking_status': 'Unknown',
#   'stroke': True}]

# %% [markdown]
# Ajouter des valeurs par défault et les conditions pour chaque filtre.
#
# Pour les types, on indique qu'il s'agit de paramètres optionels en utilisant le module python _typing_
#
# ```
# from typing import Optional
# def filter_patient(stroke_data_df: pd.DataFrame, gender: Optional[str] = None,etc)
# ```
#
# Adapter les types en utilisant ce modèle.

# %%
# fonction avec ajout de paramètres par défault et de type
from typing import Optional

def filter_patient(df_value:pd.DataFrame, gender:Optional[str] = None, stroke:Optional[bool] = None, max_age:Optional[int] = None):
    df_filtered = df_value.copy()
    
    if max_age is not None:
        df_filtered = df_filtered[df_filtered["age"] <= max_age]

    if gender is not None:
        df_filtered = df_filtered[df_filtered["gender"] == gender]

    if stroke is not None:
        df_filtered = df_filtered[df_filtered["stroke"] == stroke]

    return df_filtered.to_dict('records')

# %% [markdown]
# Tester la fonction sans argument pour les filtres, elle doit donc renvoyer le dataframe non filtré.

# %%
# test fonction sans argument pour les filtres
filter_patient(df)
# Out:
# [{'id': 9046,
#   'gender': 'Male',
#   'age': 67.0,
#   'hypertension': False,
#   'heart_disease': True,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 228.69,
#   'bmi': 36.6,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 51676,
#   'gender': 'Female',
#   'age': 61.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 202.21,
#   'bmi': 61.8,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 31112,
#   'gender': 'Male',
#   'age': 80.0,
#   'hypertension': False,
#   'heart_disease': True,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 105.92,
#   'bmi': 32.5,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 60182,
#   'gender': 'Female',
#   'age': 49.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 171.23,
#   'bmi': 34.4,
#   'smoking_status': 'Smokes',
#   'stroke': True},
#  {'id': 1665,
#   'gender': 'Female',
#   'age': 79.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 174.12,
#   'bmi': 24.0,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 56669,
#   'gender': 'Male',
#   'age': 81.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 186.21,
#   'bmi': 29.0,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 53882,
#   'gender': 'Male',
#   'age': 74.0,
#   'hypertension': True,
#   'heart_disease': True,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 70.09,
#   'bmi': 27.4,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 10434,
#   'gender': 'Female',
#   'age': 69.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 94.39,
#   'bmi': 22.8,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 27419,
#   'gender': 'Female',
#   'age': 59.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 76.15,
#   'bmi': 23.3,
#   'smoking_status': 'Unknown',
#   'stroke': True},
#  {'id': 60491,
#   'gender': 'Female',
#   'age': 78.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 58.57,
#   'bmi': 24.2,
#   'smoking_status': 'Unknown',
#   'stroke': True},
#  {'id': 12109,
#   'gender': 'Female',
#   'age': 81.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 80.43,
#   'bmi': 29.7,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 12095,
#   'gender': 'Female',
#   'age': 61.0,
#   'hypertension': False,
#   'heart_disease': True,
#   'ever_married': True,
#   'work_type': 'Government job',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 120.46,
#   'bmi': 36.8,
#   'smoking_status': 'Smokes',
#   'stroke': True},
#  {'id': 12175,
#   'gender': 'Female',
#   'age': 54.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 104.51,
#   'bmi': 27.3,
#   'smoking_status': 'Smokes',
#   'stroke': True},
#  {'id': 8213,
#   'gender': 'Male',
#   'age': 78.0,
#   'hypertension': False,
#   'heart_disease': True,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 219.84,
#   'bmi': 67.2,
#   'smoking_status': 'Unknown',
#   'stroke': True},
#  {'id': 5317,
#   'gender': 'Female',
#   'age': 79.0,
#   'hypertension': False,
#   'heart_disease': True,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 214.09,
#   'bmi': 28.2,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 58202,
#   'gender': 'Female',
#   'age': 50.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 167.41,
#   'bmi': 30.9,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 56112,
#   'gender': 'Male',
#   'age': 64.0,
#   'hypertension': False,
#   'heart_disease': True,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 191.61,
#   'bmi': 37.5,
#   'smoking_status': 'Smokes',
#   'stroke': True},
#  {'id': 34120,
#   'gender': 'Male',
#   'age': 75.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 221.29,
#   'bmi': 25.8,
#   'smoking_status': 'Smokes',
#   'stroke': True},
#  {'id': 27458,
#   'gender': 'Female',
#   'age': 60.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 89.22,
#   'bmi': 37.8,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 25226,
#   'gender': 'Male',
#   'age': 57.0,
#   'hypertension': False,
#   'heart_disease': True,
#   'ever_married': False,
#   'work_type': 'Government job',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 217.08,
#   'bmi': 66.4,
#   'smoking_status': 'Unknown',
#   'stroke': True},
#  {'id': 70630,
#   'gender': 'Female',
#   'age': 71.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Government job',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 193.94,
#   'bmi': 22.4,
#   'smoking_status': 'Smokes',
#   'stroke': True},
#  {'id': 13861,
#   'gender': 'Female',
#   'age': 52.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 233.29,
#   'bmi': 48.9,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 68794,
#   'gender': 'Female',
#   'age': 79.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 228.7,
#   'bmi': 26.6,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 64778,
#   'gender': 'Male',
#   'age': 82.0,
#   'hypertension': False,
#   'heart_disease': True,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 208.3,
#   'bmi': 32.5,
#   'smoking_status': 'Unknown',
#   'stroke': True},
#  {'id': 4219,
#   'gender': 'Male',
#   'age': 71.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 102.87,
#   'bmi': 27.2,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 70822,
#   'gender': 'Male',
#   'age': 80.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 104.12,
#   'bmi': 23.5,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 38047,
#   'gender': 'Female',
#   'age': 65.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 100.98,
#   'bmi': 28.2,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 61843,
#   'gender': 'Male',
#   'age': 58.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 189.84,
#   'bmi': 58.1,
#   'smoking_status': 'Unknown',
#   'stroke': True},
#  {'id': 54827,
#   'gender': 'Male',
#   'age': 69.0,
#   'hypertension': False,
#   'heart_disease': True,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 195.23,
#   'bmi': 28.3,
#   'smoking_status': 'Smokes',
#   'stroke': True},
#  {'id': 69160,
#   'gender': 'Male',
#   'age': 59.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 211.78,
#   'bmi': 64.8,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 43717,
#   'gender': 'Male',
#   'age': 57.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 212.08,
#   'bmi': 44.2,
#   'smoking_status': 'Smokes',
#   'stroke': True},
#  {'id': 33879,
#   'gender': 'Male',
#   'age': 42.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 83.41,
#   'bmi': 25.4,
#   'smoking_status': 'Unknown',
#   'stroke': True},
#  {'id': 39373,
#   'gender': 'Female',
#   'age': 82.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 196.92,
#   'bmi': 22.2,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 54401,
#   'gender': 'Male',
#   'age': 80.0,
#   'hypertension': False,
#   'heart_disease': True,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 252.72,
#   'bmi': 30.5,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 14248,
#   'gender': 'Male',
#   'age': 48.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Government job',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 84.2,
#   'bmi': 29.7,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 712,
#   'gender': 'Female',
#   'age': 82.0,
#   'hypertension': True,
#   'heart_disease': True,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 84.03,
#   'bmi': 26.5,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 47269,
#   'gender': 'Male',
#   'age': 74.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 219.72,
#   'bmi': 33.7,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 24977,
#   'gender': 'Female',
#   'age': 72.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 74.63,
#   'bmi': 23.1,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 47306,
#   'gender': 'Male',
#   'age': 58.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 92.62,
#   'bmi': 32.0,
#   'smoking_status': 'Unknown',
#   'stroke': True},
#  {'id': 62602,
#   'gender': 'Female',
#   'age': 49.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 60.91,
#   'bmi': 29.9,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 4651,
#   'gender': 'Male',
#   'age': 78.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 78.03,
#   'bmi': 23.9,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 1261,
#   'gender': 'Male',
#   'age': 54.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 71.22,
#   'bmi': 28.5,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 61960,
#   'gender': 'Male',
#   'age': 82.0,
#   'hypertension': False,
#   'heart_disease': True,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 144.9,
#   'bmi': 26.4,
#   'smoking_status': 'Smokes',
#   'stroke': True},
#  {'id': 1845,
#   'gender': 'Female',
#   'age': 63.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 90.9,
#   'bmi': 27.8,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 7937,
#   'gender': 'Male',
#   'age': 60.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Government job',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 213.03,
#   'bmi': 20.2,
#   'smoking_status': 'Smokes',
#   'stroke': True},
#  {'id': 19824,
#   'gender': 'Male',
#   'age': 76.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 243.58,
#   'bmi': 33.6,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 37937,
#   'gender': 'Female',
#   'age': 75.0,
#   'hypertension': False,
#   'heart_disease': True,
#   'ever_married': False,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 109.78,
#   'bmi': 33.6,
#   'smoking_status': 'Unknown',
#   'stroke': True},
#  {'id': 47472,
#   'gender': 'Female',
#   'age': 58.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 107.26,
#   'bmi': 38.6,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 35626,
#   'gender': 'Male',
#   'age': 81.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 99.33,
#   'bmi': 33.7,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 36338,
#   'gender': 'Female',
#   'age': 39.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 58.09,
#   'bmi': 39.2,
#   'smoking_status': 'Smokes',
#   'stroke': True},
#  {'id': 18587,
#   'gender': 'Female',
#   'age': 76.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 89.96,
#   'bmi': 27.5,
#   'smoking_status': 'Unknown',
#   'stroke': True},
#  {'id': 15102,
#   'gender': 'Male',
#   'age': 78.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 75.32,
#   'bmi': 23.0,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 59190,
#   'gender': 'Female',
#   'age': 79.0,
#   'hypertension': False,
#   'heart_disease': True,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 127.29,
#   'bmi': 27.7,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 47167,
#   'gender': 'Female',
#   'age': 77.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 124.13,
#   'bmi': 31.4,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 8752,
#   'gender': 'Female',
#   'age': 63.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Government job',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 197.54,
#   'bmi': 60.4,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 25831,
#   'gender': 'Male',
#   'age': 63.0,
#   'hypertension': False,
#   'heart_disease': True,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 196.71,
#   'bmi': 36.5,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 38829,
#   'gender': 'Female',
#   'age': 82.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 59.32,
#   'bmi': 33.2,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 66400,
#   'gender': 'Male',
#   'age': 78.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 237.75,
#   'bmi': 72.7,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 58631,
#   'gender': 'Male',
#   'age': 73.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 194.99,
#   'bmi': 32.8,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 5111,
#   'gender': 'Female',
#   'age': 54.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Government job',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 180.93,
#   'bmi': 27.7,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 10710,
#   'gender': 'Female',
#   'age': 56.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 185.17,
#   'bmi': 40.4,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 55927,
#   'gender': 'Female',
#   'age': 80.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 74.9,
#   'bmi': 22.2,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 65842,
#   'gender': 'Female',
#   'age': 67.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 61.94,
#   'bmi': 25.3,
#   'smoking_status': 'Smokes',
#   'stroke': True},
#  {'id': 19557,
#   'gender': 'Female',
#   'age': 45.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 93.72,
#   'bmi': 30.2,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 7356,
#   'gender': 'Male',
#   'age': 75.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 104.72,
#   'bmi': 32.0,
#   'smoking_status': 'Unknown',
#   'stroke': True},
#  {'id': 17013,
#   'gender': 'Male',
#   'age': 78.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 113.01,
#   'bmi': 24.0,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 17004,
#   'gender': 'Female',
#   'age': 70.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 221.58,
#   'bmi': 47.5,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 72366,
#   'gender': 'Male',
#   'age': 76.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 104.47,
#   'bmi': 20.3,
#   'smoking_status': 'Unknown',
#   'stroke': True},
#  {'id': 6118,
#   'gender': 'Male',
#   'age': 59.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 86.23,
#   'bmi': 30.0,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 7371,
#   'gender': 'Female',
#   'age': 80.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 72.67,
#   'bmi': 28.9,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 70676,
#   'gender': 'Female',
#   'age': 76.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Government job',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 62.57,
#   'bmi': 19.1,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 2326,
#   'gender': 'Female',
#   'age': 67.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 179.12,
#   'bmi': 28.1,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 27169,
#   'gender': 'Female',
#   'age': 66.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Government job',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 116.55,
#   'bmi': 31.1,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 50784,
#   'gender': 'Male',
#   'age': 63.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 228.56,
#   'bmi': 27.4,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 19773,
#   'gender': 'Female',
#   'age': 52.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 96.59,
#   'bmi': 26.4,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 66159,
#   'gender': 'Female',
#   'age': 80.0,
#   'hypertension': False,
#   'heart_disease': True,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 66.72,
#   'bmi': 21.7,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 36236,
#   'gender': 'Male',
#   'age': 80.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 240.09,
#   'bmi': 27.0,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 71673,
#   'gender': 'Female',
#   'age': 79.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 110.85,
#   'bmi': 24.1,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 45805,
#   'gender': 'Female',
#   'age': 51.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 165.31,
#   'bmi': 50.6,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 42117,
#   'gender': 'Male',
#   'age': 43.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 143.43,
#   'bmi': 45.9,
#   'smoking_status': 'Unknown',
#   'stroke': True},
#  {'id': 57419,
#   'gender': 'Male',
#   'age': 59.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 96.16,
#   'bmi': 44.1,
#   'smoking_status': 'Unknown',
#   'stroke': True},
#  {'id': 26015,
#   'gender': 'Female',
#   'age': 66.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 101.45,
#   'bmi': 31.0,
#   'smoking_status': 'Unknown',
#   'stroke': True},
#  {'id': 26727,
#   'gender': 'Female',
#   'age': 79.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 88.92,
#   'bmi': 22.9,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 66638,
#   'gender': 'Female',
#   'age': 68.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 79.79,
#   'bmi': 29.7,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 70042,
#   'gender': 'Male',
#   'age': 58.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 71.2,
#   'bmi': 21.8,
#   'smoking_status': 'Unknown',
#   'stroke': True},
#  {'id': 32399,
#   'gender': 'Male',
#   'age': 54.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 96.97,
#   'bmi': 29.1,
#   'smoking_status': 'Smokes',
#   'stroke': True},
#  {'id': 3253,
#   'gender': 'Male',
#   'age': 61.0,
#   'hypertension': False,
#   'heart_disease': True,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 111.81,
#   'bmi': 27.3,
#   'smoking_status': 'Smokes',
#   'stroke': True},
#  {'id': 71796,
#   'gender': 'Female',
#   'age': 70.0,
#   'hypertension': False,
#   'heart_disease': True,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 59.35,
#   'bmi': 32.3,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 14499,
#   'gender': 'Male',
#   'age': 47.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 86.94,
#   'bmi': 41.1,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 49130,
#   'gender': 'Male',
#   'age': 74.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 98.55,
#   'bmi': 25.6,
#   'smoking_status': 'Unknown',
#   'stroke': True},
#  {'id': 28291,
#   'gender': 'Female',
#   'age': 79.0,
#   'hypertension': False,
#   'heart_disease': True,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 226.98,
#   'bmi': 29.8,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 51169,
#   'gender': 'Male',
#   'age': 81.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 72.81,
#   'bmi': 26.3,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 66315,
#   'gender': 'Female',
#   'age': 57.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 68.02,
#   'bmi': 37.5,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 37726,
#   'gender': 'Female',
#   'age': 80.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 68.56,
#   'bmi': 26.2,
#   'smoking_status': 'Unknown',
#   'stroke': True},
#  {'id': 54385,
#   'gender': 'Male',
#   'age': 45.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 64.14,
#   'bmi': 29.4,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 2458,
#   'gender': 'Female',
#   'age': 78.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 235.63,
#   'bmi': 32.3,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 35512,
#   'gender': 'Female',
#   'age': 70.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 76.34,
#   'bmi': 24.4,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 56841,
#   'gender': 'Male',
#   'age': 58.0,
#   'hypertension': False,
#   'heart_disease': True,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 240.59,
#   'bmi': 31.4,
#   'smoking_status': 'Smokes',
#   'stroke': True},
#  {'id': 8154,
#   'gender': 'Male',
#   'age': 57.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Government job',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 78.92,
#   'bmi': 27.7,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 4639,
#   'gender': 'Female',
#   'age': 69.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Government job',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 82.81,
#   'bmi': 28.0,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 12363,
#   'gender': 'Male',
#   'age': 64.0,
#   'hypertension': False,
#   'heart_disease': True,
#   'ever_married': True,
#   'work_type': 'Government job',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 74.1,
#   'bmi': 28.8,
#   'smoking_status': 'Unknown',
#   'stroke': True},
#  {'id': 63973,
#   'gender': 'Female',
#   'age': 77.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Government job',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 190.32,
#   'bmi': 31.4,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 45277,
#   'gender': 'Female',
#   'age': 74.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 231.61,
#   'bmi': 34.6,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 4712,
#   'gender': 'Female',
#   'age': 81.0,
#   'hypertension': False,
#   'heart_disease': True,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 78.7,
#   'bmi': 19.4,
#   'smoking_status': 'Unknown',
#   'stroke': True},
#  {'id': 33175,
#   'gender': 'Female',
#   'age': 57.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Government job',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 110.52,
#   'bmi': 28.5,
#   'smoking_status': 'Unknown',
#   'stroke': True},
#  {'id': 2346,
#   'gender': 'Male',
#   'age': 58.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 82.3,
#   'bmi': 25.2,
#   'smoking_status': 'Smokes',
#   'stroke': True},
#  {'id': 42072,
#   'gender': 'Female',
#   'age': 50.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 73.18,
#   'bmi': 30.3,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 12062,
#   'gender': 'Female',
#   'age': 54.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 191.82,
#   'bmi': 40.4,
#   'smoking_status': 'Smokes',
#   'stroke': True},
#  {'id': 30456,
#   'gender': 'Female',
#   'age': 79.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 93.05,
#   'bmi': 24.2,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 59125,
#   'gender': 'Female',
#   'age': 53.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Government job',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 64.17,
#   'bmi': 41.5,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 56546,
#   'gender': 'Male',
#   'age': 79.0,
#   'hypertension': False,
#   'heart_disease': True,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 129.98,
#   'bmi': 22.6,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 48405,
#   'gender': 'Male',
#   'age': 80.0,
#   'hypertension': False,
#   'heart_disease': True,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 68.53,
#   'bmi': 24.2,
#   'smoking_status': 'Smokes',
#   'stroke': True},
#  {'id': 36706,
#   'gender': 'Female',
#   'age': 76.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 106.41,
#   'bmi': 32.5,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 41069,
#   'gender': 'Female',
#   'age': 45.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 224.1,
#   'bmi': 56.6,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 71639,
#   'gender': 'Female',
#   'age': 68.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Government job',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 82.1,
#   'bmi': 27.1,
#   'smoking_status': 'Unknown',
#   'stroke': True},
#  {'id': 53401,
#   'gender': 'Male',
#   'age': 71.0,
#   'hypertension': True,
#   'heart_disease': True,
#   'ever_married': False,
#   'work_type': 'Government job',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 216.94,
#   'bmi': 30.9,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 60744,
#   'gender': 'Male',
#   'age': 61.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 76.11,
#   'bmi': 27.3,
#   'smoking_status': 'Smokes',
#   'stroke': True},
#  {'id': 7547,
#   'gender': 'Male',
#   'age': 74.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 72.96,
#   'bmi': 31.3,
#   'smoking_status': 'Smokes',
#   'stroke': True},
#  {'id': 31720,
#   'gender': 'Female',
#   'age': 38.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 82.28,
#   'bmi': 24.0,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 5563,
#   'gender': 'Female',
#   'age': 77.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 105.22,
#   'bmi': 31.0,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 68798,
#   'gender': 'Female',
#   'age': 58.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 59.86,
#   'bmi': 28.0,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 72918,
#   'gender': 'Female',
#   'age': 53.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 62.55,
#   'bmi': 30.3,
#   'smoking_status': 'Unknown',
#   'stroke': True},
#  {'id': 13491,
#   'gender': 'Male',
#   'age': 80.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 259.63,
#   'bmi': 31.7,
#   'smoking_status': 'Smokes',
#   'stroke': True},
#  {'id': 44033,
#   'gender': 'Male',
#   'age': 56.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 249.31,
#   'bmi': 35.8,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 14164,
#   'gender': 'Female',
#   'age': 72.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 219.91,
#   'bmi': 67.3,
#   'smoking_status': 'Unknown',
#   'stroke': True},
#  {'id': 50522,
#   'gender': 'Female',
#   'age': 72.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Government job',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 131.41,
#   'bmi': 28.4,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 3352,
#   'gender': 'Male',
#   'age': 78.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 93.13,
#   'bmi': 28.5,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 70943,
#   'gender': 'Female',
#   'age': 80.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 73.54,
#   'bmi': 24.0,
#   'smoking_status': 'Unknown',
#   'stroke': True},
#  {'id': 37132,
#   'gender': 'Male',
#   'age': 82.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Government job',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 200.59,
#   'bmi': 29.0,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 48796,
#   'gender': 'Female',
#   'age': 75.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Government job',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 62.48,
#   'bmi': 19.1,
#   'smoking_status': 'Unknown',
#   'stroke': True},
#  {'id': 53440,
#   'gender': 'Female',
#   'age': 73.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 190.14,
#   'bmi': 36.5,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 16817,
#   'gender': 'Female',
#   'age': 78.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 130.54,
#   'bmi': 20.1,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 69551,
#   'gender': 'Male',
#   'age': 69.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 182.99,
#   'bmi': 36.5,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 31563,
#   'gender': 'Female',
#   'age': 38.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 101.45,
#   'bmi': 31.0,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 20387,
#   'gender': 'Female',
#   'age': 68.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 206.09,
#   'bmi': 26.7,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 71279,
#   'gender': 'Female',
#   'age': 71.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Government job',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 263.32,
#   'bmi': 38.7,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 55824,
#   'gender': 'Male',
#   'age': 76.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 140.1,
#   'bmi': 29.9,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 11762,
#   'gender': 'Female',
#   'age': 76.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 207.28,
#   'bmi': 34.9,
#   'smoking_status': 'Unknown',
#   'stroke': True},
#  {'id': 29281,
#   'gender': 'Male',
#   'age': 76.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 194.37,
#   'bmi': 27.0,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 30683,
#   'gender': 'Female',
#   'age': 75.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 199.2,
#   'bmi': 26.6,
#   'smoking_status': 'Unknown',
#   'stroke': True},
#  {'id': 20439,
#   'gender': 'Male',
#   'age': 82.0,
#   'hypertension': False,
#   'heart_disease': True,
#   'ever_married': True,
#   'work_type': 'Government job',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 103.68,
#   'bmi': 25.0,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 45965,
#   'gender': 'Female',
#   'age': 59.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 116.44,
#   'bmi': 23.8,
#   'smoking_status': 'Smokes',
#   'stroke': True},
#  {'id': 8045,
#   'gender': 'Female',
#   'age': 74.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 70.28,
#   'bmi': 21.8,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 37651,
#   'gender': 'Female',
#   'age': 69.0,
#   'hypertension': True,
#   'heart_disease': True,
#   'ever_married': False,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 72.17,
#   'bmi': 36.8,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 17308,
#   'gender': 'Female',
#   'age': 72.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 221.79,
#   'bmi': 30.0,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 67981,
#   'gender': 'Male',
#   'age': 66.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 151.16,
#   'bmi': 27.5,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 41241,
#   'gender': 'Male',
#   'age': 65.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 68.43,
#   'bmi': 20.9,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 62861,
#   'gender': 'Female',
#   'age': 78.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 67.29,
#   'bmi': 24.6,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 72081,
#   'gender': 'Female',
#   'age': 57.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Government job',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 67.41,
#   'bmi': 32.9,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 58978,
#   'gender': 'Female',
#   'age': 70.0,
#   'hypertension': False,
#   'heart_disease': True,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 239.07,
#   'bmi': 26.1,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 11933,
#   'gender': 'Female',
#   'age': 79.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 169.67,
#   'bmi': 51.9,
#   'smoking_status': 'Unknown',
#   'stroke': True},
#  {'id': 46703,
#   'gender': 'Male',
#   'age': 68.0,
#   'hypertension': False,
#   'heart_disease': True,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 223.83,
#   'bmi': 31.9,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 32503,
#   'gender': 'Female',
#   'age': 80.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 76.57,
#   'bmi': 34.1,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 12482,
#   'gender': 'Male',
#   'age': 68.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 77.82,
#   'bmi': 27.5,
#   'smoking_status': 'Smokes',
#   'stroke': True},
#  {'id': 56939,
#   'gender': 'Female',
#   'age': 55.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 92.98,
#   'bmi': 25.6,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 24669,
#   'gender': 'Female',
#   'age': 77.0,
#   'hypertension': False,
#   'heart_disease': True,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 231.56,
#   'bmi': 36.9,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 43054,
#   'gender': 'Female',
#   'age': 50.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 102.16,
#   'bmi': 31.4,
#   'smoking_status': 'Smokes',
#   'stroke': True},
#  {'id': 59437,
#   'gender': 'Female',
#   'age': 57.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 221.89,
#   'bmi': 37.3,
#   'smoking_status': 'Smokes',
#   'stroke': True},
#  {'id': 66258,
#   'gender': 'Female',
#   'age': 71.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 195.71,
#   'bmi': 34.1,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 34567,
#   'gender': 'Female',
#   'age': 81.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 74.02,
#   'bmi': 25.0,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 50931,
#   'gender': 'Female',
#   'age': 76.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 57.92,
#   'bmi': 17.7,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 16590,
#   'gender': 'Male',
#   'age': 71.0,
#   'hypertension': False,
#   'heart_disease': True,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 81.76,
#   'bmi': 25.0,
#   'smoking_status': 'Smokes',
#   'stroke': True},
#  {'id': 69768,
#   'gender': 'Female',
#   'age': 1.32,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Children',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 70.37,
#   'bmi': 21.5,
#   'smoking_status': 'Unknown',
#   'stroke': True},
#  {'id': 20426,
#   'gender': 'Female',
#   'age': 78.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 203.87,
#   'bmi': 45.7,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 3512,
#   'gender': 'Female',
#   'age': 70.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 89.13,
#   'bmi': 34.2,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 42899,
#   'gender': 'Male',
#   'age': 78.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 133.19,
#   'bmi': 23.6,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 63453,
#   'gender': 'Female',
#   'age': 56.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Government job',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 162.23,
#   'bmi': 27.3,
#   'smoking_status': 'Unknown',
#   'stroke': True},
#  {'id': 43364,
#   'gender': 'Male',
#   'age': 79.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 75.02,
#   'bmi': 22.9,
#   'smoking_status': 'Never smoked',
#   'stroke': True},
#  {'id': 44993,
#   'gender': 'Female',
#   'age': 79.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Government job',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 98.02,
#   'bmi': 22.3,
#   'smoking_status': 'Formerly smoked',
#   'stroke': True},
#  {'id': 210,
#   'gender': 'Male',
#   'age': 81.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 91.54,
#   'bmi': 31.4,
# ...
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 86.4,
#   'bmi': 42.6,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 44105,
#   'gender': 'Female',
#   'age': 69.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 61.81,
#   'bmi': 37.1,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 65256,
#   'gender': 'Female',
#   'age': 57.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 128.28,
#   'bmi': 34.2,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 62709,
#   'gender': 'Female',
#   'age': 47.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 204.63,
#   'bmi': 43.4,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 36698,
#   'gender': 'Female',
#   'age': 33.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 89.98,
#   'bmi': 18.7,
#   'smoking_status': 'Smokes',
#   'stroke': False},
#  {'id': 7273,
#   'gender': 'Female',
#   'age': 51.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 232.89,
#   'bmi': 34.0,
#   'smoking_status': 'Smokes',
#   'stroke': False},
#  {'id': 20044,
#   'gender': 'Female',
#   'age': 47.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 98.58,
#   'bmi': 23.2,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 54769,
#   'gender': 'Male',
#   'age': 15.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 57.94,
#   'bmi': 41.7,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 57372,
#   'gender': 'Male',
#   'age': 1.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Children',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 123.21,
#   'bmi': 15.1,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 30605,
#   'gender': 'Female',
#   'age': 20.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 76.34,
#   'bmi': 20.6,
#   'smoking_status': 'Smokes',
#   'stroke': False},
#  {'id': 13622,
#   'gender': 'Male',
#   'age': 6.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Children',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 92.98,
#   'bmi': 18.9,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 12686,
#   'gender': 'Male',
#   'age': 50.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Government job',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 92.81,
#   'bmi': 26.6,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 39250,
#   'gender': 'Male',
#   'age': 31.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 85.16,
#   'bmi': 30.1,
#   'smoking_status': 'Smokes',
#   'stroke': False},
#  {'id': 2879,
#   'gender': 'Female',
#   'age': 15.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 90.1,
#   'bmi': 32.1,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 59684,
#   'gender': 'Female',
#   'age': 3.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Children',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 65.15,
#   'bmi': 15.1,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 48830,
#   'gender': 'Male',
#   'age': 30.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 104.62,
#   'bmi': 33.5,
#   'smoking_status': 'Smokes',
#   'stroke': False},
#  {'id': 56986,
#   'gender': 'Male',
#   'age': 17.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Never worked',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 113.25,
#   'bmi': 23.4,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 47924,
#   'gender': 'Male',
#   'age': 24.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 59.28,
#   'bmi': 43.2,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 16402,
#   'gender': 'Female',
#   'age': 5.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Children',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 93.07,
#   'bmi': 19.1,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 40889,
#   'gender': 'Male',
#   'age': 33.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 77.42,
#   'bmi': 26.1,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 4083,
#   'gender': 'Female',
#   'age': 30.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 73.69,
#   'bmi': 17.3,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 59336,
#   'gender': 'Male',
#   'age': 66.0,
#   'hypertension': True,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 74.9,
#   'bmi': 32.1,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 5684,
#   'gender': 'Male',
#   'age': 40.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 88.27,
#   'bmi': 27.0,
#   'smoking_status': 'Formerly smoked',
#   'stroke': False},
#  {'id': 48843,
#   'gender': 'Female',
#   'age': 27.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 58.39,
#   'bmi': 30.4,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 5694,
#   'gender': 'Male',
#   'age': 21.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 102.05,
#   'bmi': 29.9,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 3673,
#   'gender': 'Female',
#   'age': 55.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 112.47,
#   'bmi': 32.8,
#   'smoking_status': 'Smokes',
#   'stroke': False},
#  {'id': 44481,
#   'gender': 'Female',
#   'age': 19.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 72.84,
#   'bmi': 22.7,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 10538,
#   'gender': 'Male',
#   'age': 75.0,
#   'hypertension': True,
#   'heart_disease': True,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 195.03,
#   'bmi': 28.7,
#   'smoking_status': 'Formerly smoked',
#   'stroke': False},
#  {'id': 9648,
#   'gender': 'Female',
#   'age': 71.0,
#   'hypertension': False,
#   'heart_disease': True,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 170.95,
#   'bmi': 35.2,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 19101,
#   'gender': 'Female',
#   'age': 16.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 87.98,
#   'bmi': 22.4,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 31867,
#   'gender': 'Female',
#   'age': 49.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 65.81,
#   'bmi': 32.3,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 11973,
#   'gender': 'Female',
#   'age': 10.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Children',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 124.6,
#   'bmi': 18.6,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 23633,
#   'gender': 'Female',
#   'age': 37.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 83.65,
#   'bmi': 42.1,
#   'smoking_status': 'Smokes',
#   'stroke': False},
#  {'id': 52549,
#   'gender': 'Male',
#   'age': 59.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Government job',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 88.81,
#   'bmi': 38.0,
#   'smoking_status': 'Formerly smoked',
#   'stroke': False},
#  {'id': 59178,
#   'gender': 'Female',
#   'age': 7.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Children',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 86.75,
#   'bmi': 22.3,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 37349,
#   'gender': 'Female',
#   'age': 61.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 123.36,
#   'bmi': 33.4,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 44281,
#   'gender': 'Male',
#   'age': 34.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 89.68,
#   'bmi': 23.2,
#   'smoking_status': 'Smokes',
#   'stroke': False},
#  {'id': 55599,
#   'gender': 'Female',
#   'age': 9.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Children',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 69.87,
#   'bmi': 18.0,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 45224,
#   'gender': 'Female',
#   'age': 46.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 109.22,
#   'bmi': 20.1,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 54747,
#   'gender': 'Male',
#   'age': 0.88,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Children',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 157.57,
#   'bmi': 19.2,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 2751,
#   'gender': 'Male',
#   'age': 50.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Government job',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 110.73,
#   'bmi': 28.7,
#   'smoking_status': 'Smokes',
#   'stroke': False},
#  {'id': 6090,
#   'gender': 'Male',
#   'age': 19.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 99.14,
#   'bmi': 28.1,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 46385,
#   'gender': 'Female',
#   'age': 21.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 59.15,
#   'bmi': 22.6,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 46323,
#   'gender': 'Female',
#   'age': 2.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Children',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 165.11,
#   'bmi': 18.0,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 28122,
#   'gender': 'Female',
#   'age': 37.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 77.44,
#   'bmi': 21.4,
#   'smoking_status': 'Formerly smoked',
#   'stroke': False},
#  {'id': 50843,
#   'gender': 'Male',
#   'age': 20.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 100.33,
#   'bmi': 27.8,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 64464,
#   'gender': 'Male',
#   'age': 50.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 57.93,
#   'bmi': 27.6,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 66922,
#   'gender': 'Male',
#   'age': 61.0,
#   'hypertension': True,
#   'heart_disease': True,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 148.24,
#   'bmi': 32.2,
#   'smoking_status': 'Formerly smoked',
#   'stroke': False},
#  {'id': 66494,
#   'gender': 'Male',
#   'age': 48.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 91.96,
#   'bmi': 24.9,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 42786,
#   'gender': 'Male',
#   'age': 82.0,
#   'hypertension': False,
#   'heart_disease': True,
#   'ever_married': True,
#   'work_type': 'Self-employed',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 72.93,
#   'bmi': 27.1,
#   'smoking_status': 'Formerly smoked',
#   'stroke': False},
#  {'id': 33401,
#   'gender': 'Male',
#   'age': 64.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 84.27,
#   'bmi': 24.6,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 24174,
#   'gender': 'Female',
#   'age': 50.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Government job',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 124.45,
#   'bmi': 24.6,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 60211,
#   'gender': 'Male',
#   'age': 1.4,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Children',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 90.51,
#   'bmi': 18.9,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 53279,
#   'gender': 'Male',
#   'age': 0.24,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Children',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 118.87,
#   'bmi': 16.3,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 61715,
#   'gender': 'Male',
#   'age': 55.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': True,
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 56.42,
#   'bmi': 31.8,
#   'smoking_status': 'Never smoked',
#   'stroke': False},
#  {'id': 37830,
#   'gender': 'Female',
#   'age': 29.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 73.67,
#   'bmi': 21.0,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  {'id': 2454,
#   'gender': 'Male',
#   'age': 4.0,
#   'hypertension': False,
#   'heart_disease': False,
#   'ever_married': False,
#   'work_type': 'Children',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 89.11,
#   'bmi': 20.1,
#   'smoking_status': 'Unknown',
#   'stroke': False},
#  ...]

# %% [markdown]
# Cette fonction va être utilisée dans la définition de l'API pour créer une route qui permette d'accéder à des données filtrées sur les patients.
#
# Dans le fichier de définition de l'API, toutes les fonctions vont travailler sur les données du fichier.
#
# Pour alléger les fonctions on va donc utiliser une **variable globale** pour les données et supprimer le paramètre `df` de la fonction.
#
# On lit les données en début de fichier puis on travaille au sein des fonctions sur une copie du dataframe de données.
#
#
# **En résumé les modifications à faire sont :**
#
#
# - Supprimer le paramètre df de la fonction,
# - Ajouter en début de fonction :
# ```df = stroke_data_df.copy()```
#
# 1. Dans le fichier filters.py, il suffit d'ajouter :
# - lecture du fichier de données prétraitée dans la variable *df* en début de fichier (utiliser pandas),
# - @app.get("/patients/") pour définir le route,
# puis la fonction.
#
# 2. Dans le fichier api.py: appeler la fonction dans la route correspondante.
#
# Tester la route avec
#
# ```poetry run fastapi dev stroke_api/main.py```
#
# http://127.0.0.1:8000/docs : utiliser la fonctionnalité Try it out pour tester la route.

# %% [markdown]
# ---
# ## Autres routes
#
# De la même manière, créer les fonctions appropriées pour la création de :
# - la route `/patients/{id}` : Récupère les détails d’un patient donné (via son identifiant unique)
#
# - la route `/stats/` : Fournit des statistiques agrégées sur les patients (ex. : nb total de patients, âge moyen, taux d’AVC, répartition hommes/femmes).
#
# - Lister les tâches à faire sous forme d'issue github : travailler sur une branche différentes pour l'ajout de chacune des routes.

# %% [markdown]
# STATS

# %%
def stats(type:Optional[str] = None):
    df1 = df.copy()

    if type is None:
        fig  = px.pie()

# %%
def filter_id(id_patient:int):
    df1 = df.copy()

    if id_patient in df1["id"].tolist():
        return df1.loc[df1["id"] == id_patient].to_dict('records')
    else:
        return print("Ce patient id n'existe pas")

# %%
filter_id(2)
# Out:
# Ce patient id n'existe pas

# %%
nb_patient = df["id"].count()
age_moyen =  df["age"].mean()
avc_moyen = df["stroke"].mean()

print(f"{round(nb_patient)} patients, ", f"{round(age_moyen)} ans en moyenne, ", f"{avc_moyen}% taux d'avc")
# Out:
# 5110 patients,  43 ans en moyenne,  0.0487279843444227% taux d'avc
